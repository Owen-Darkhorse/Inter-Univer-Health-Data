# %%
import statsmodels.api as sm
import statsmodels.formula.api as smf
import pandas as pd
import numpy as np
from sklearn.model_selection import GroupShuffleSplit

hrsWave = pd.read_csv("../Data/hrsWaveCleaned.csv")

# n = 1000
# hhidpn = np.random.choice(hrsWave["HHIDPN"].unique(), size = n)
# idx = hrsWave["HHIDPN"].isin(hhidpn)
# df = hrsWave.loc[idx, :]

gss = GroupShuffleSplit(n_splits=2, test_size = 0.3)
groupVar = hrsWave["HHIDPN"]
# gss.split(X = hrsWave, groups=groupVar)
shuffle_1, shuffle_2 = gss.split(X = hrsWave, groups=groupVar)
trainIndex, testIndex = shuffle_1
print(trainIndex)
print(testIndex)

## Subset Training and Test Set
df = hrsWave.iloc[trainIndex, :]
testSet = hrsWave.iloc[testIndex, :]

# 1. Define the Binomial family and logit link
# The `Binomial` family in statsmodels assumes endog is proportions (e.g., successes/n_trials)
# or a 2-column array where col 0 is successes and col 1 is failures.
# Since your score is 0-20, you should pass it as a two-column array: [recall_score, 20 - recall_score]


# Create a 2-column array for endog if using the formula API with a non-standard endog
# For GEE with Binomial, endog usually expects a proportion (successes/n_trials) or a (successes, total_trials) tuple/array
# If using `smf.gee`, it's often more straightforward to define `endog` as proportion.
n_trials = 20
df['RwRecProp'] = df['RwTR20'] / n_trials
testSet['RwRecProp'] = testSet['RwTR20'] / n_trials
# Out:
# [     0      1      2 ... 130682 130685 130686]
# [    23     38     39 ... 130646 130683 130684]
# C:\Users\86139\AppData\Local\Temp\ipykernel_16484\1228542345.py:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['RwRecProp'] = df['RwTR20'] / n_trials
# C:\Users\86139\AppData\Local\Temp\ipykernel_16484\1228542345.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   testSet['RwRecProp'] = testSet['RwTR20'] / n_trials

# %%
print(df.shape)
print(testSet.shape)
# Out:
# (91356, 47)
# (39331, 47)

# %%
df.to_csv("../Data/hrsTrain.csv")
testSet.to_csv("../Data/hrsTest.csv")

# %% [markdown]
# ## 1. Fitting the Base Model

# %%
def fitBaseModel(formula, groups, df, covStruct, family):
    model = smf.gee(formula, groups=groups, data=df,
                    cov_struct=covStruct,
                    family=family).fit(cov_type = "robust")
    
    print(model.summary())
    
    return model

# 2. Define the exchangeable correlation structure
exchangeable_corr = sm.cov_struct.Exchangeable()
autoregress_corr = sm.cov_struct.Autoregressive()
indep_corr = sm.cov_struct.Independence()


# 3. Specify Full Model Formula
formulaBase = "RwRecProp ~ RwAGEM_B + C(RwJOCCSD, Treatment(reference='Retired'))"

# 4. Fit the model with robust covariance
resultsExch = fitBaseModel(formulaBase, "HHIDPN", df, exchangeable_corr, sm.families.Binomial())
resultsAR = fitBaseModel(formulaBase, "HHIDPN", df, autoregress_corr, sm.families.Binomial())
resultsIndep = fitBaseModel(formulaBase, "HHIDPN", df, indep_corr, sm.families.Binomial())
# Out:
# C:\Users\86139\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\statsmodels\genmod\cov_struct.py:796: FutureWarning: grid=True will become default in a future version
#   warnings.warn(
#                                GEE Regression Results
# ===================================================================================
# Dep. Variable:                   RwRecProp   No. Observations:                81174
# Model:                                 GEE   No. clusters:                    18613
# Method:                        Generalized   Min. cluster size:                   1
#                       Estimating Equations   Max. cluster size:                  11
# Family:                           Binomial   Mean cluster size:                 4.4
# Dependence structure:         Exchangeable   Num. iterations:                    10
# Date:                     Thu, 03 Jul 2025   Scale:                           1.000
# Covariance type:                    robust   Time:                         03:27:48
# ===================================================================================================================================================
#                                                                                       coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------------------------------------------
# Intercept                                                                           2.0654      0.027     77.591      0.000       2.013       2.118
# C(RwJOCCSD, Treatment(reference='Retired'))[T.Farming/Forestry/Fishing]            -0.0015      0.029     -0.051      0.959      -0.058       0.055
# C(RwJOCCSD, Treatment(reference='Retired'))[T.Food/Personal/Service]                0.0080      0.014      0.572      0.567      -0.019       0.035
# C(RwJOCCSD, Treatment(reference='Retired'))[T.Healthcare]                           0.0593      0.025      2.410      0.016       0.011       0.108
# C(RwJOCCSD, Treatment(reference='Retired'))[T.High Risk Occupations]                0.0112      0.037      0.304      0.761      -0.061       0.084
# C(RwJOCCSD, Treatment(reference='Retired'))[T.Management/Clerical/Business]         0.0974      0.011      9.062      0.000       0.076       0.118
# C(RwJOCCSD, Treatment(reference='Retired'))[T.STEM/Professional/Technical]          0.1475      0.014     10.597      0.000       0.120       0.175
# C(RwJOCCSD, Treatment(reference='Retired'))[T.Sales]                                0.1080      0.016      6.704      0.000       0.076       0.140
# C(RwJOCCSD, Treatment(reference='Retired'))[T.Skilled Trades/Production/Manual]    -0.0727      0.013     -5.725      0.000      -0.098      -0.048
# RwAGEM_B                                                                           -0.0343      0.000    -89.256      0.000      -0.035      -0.034
# ==============================================================================
# Skew:                          0.0534   Kurtosis:                      -0.0107
# Centered skew:                 0.0061   Centered kurtosis:              1.1474
# ==============================================================================
#                                GEE Regression Results
# ===================================================================================
# Dep. Variable:                   RwRecProp   No. Observations:                81174
# Model:                                 GEE   No. clusters:                    18613
# Method:                        Generalized   Min. cluster size:                   1
#                       Estimating Equations   Max. cluster size:                  11
# Family:                           Binomial   Mean cluster size:                 4.4
# Dependence structure:       Autoregressive   Num. iterations:                    13
# Date:                     Thu, 03 Jul 2025   Scale:                           1.000
# Covariance type:                    robust   Time:                         03:28:42
# ===================================================================================================================================================
#                                                                                       coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------------------------------------------
# Intercept                                                                           1.8770      0.029     65.095      0.000       1.820       1.934
# C(RwJOCCSD, Treatment(reference='Retired'))[T.Farming/Forestry/Fishing]            -0.0202      0.033     -0.614      0.539      -0.085       0.044
# C(RwJOCCSD, Treatment(reference='Retired'))[T.Food/Personal/Service]               -0.0032      0.015     -0.209      0.835      -0.034       0.027
# C(RwJOCCSD, Treatment(reference='Retired'))[T.Healthcare]                           0.0464      0.028      1.675      0.094      -0.008       0.101
# C(RwJOCCSD, Treatment(reference='Retired'))[T.High Risk Occupations]               -0.0191      0.046     -0.418      0.676      -0.109       0.070
# C(RwJOCCSD, Treatment(reference='Retired'))[T.Management/Clerical/Business]         0.0979      0.012      8.073      0.000       0.074       0.122
# C(RwJOCCSD, Treatment(reference='Retired'))[T.STEM/Professional/Technical]          0.1425      0.016      8.984      0.000       0.111       0.174
# C(RwJOCCSD, Treatment(reference='Retired'))[T.Sales]                                0.0888      0.017      5.089      0.000       0.055       0.123
# C(RwJOCCSD, Treatment(reference='Retired'))[T.Skilled Trades/Production/Manual]    -0.0566      0.014     -4.048      0.000      -0.084      -0.029
# RwAGEM_B                                                                           -0.0315      0.000    -75.889      0.000      -0.032      -0.031
# ==============================================================================
# Skew:                          0.0568   Kurtosis:                      -0.0182
# Centered skew:                 0.0088   Centered kurtosis:              1.1574
# ==============================================================================
#                                GEE Regression Results
# ===================================================================================
# Dep. Variable:                   RwRecProp   No. Observations:                81174
# Model:                                 GEE   No. clusters:                    18613
# Method:                        Generalized   Min. cluster size:                   1
#                       Estimating Equations   Max. cluster size:                  11
# Family:                           Binomial   Mean cluster size:                 4.4
# Dependence structure:         Independence   Num. iterations:                     2
# Date:                     Thu, 03 Jul 2025   Scale:                           1.000
# Covariance type:                    robust   Time:                         03:28:50
# ===================================================================================================================================================
#                                                                                       coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------------------------------------------
# Intercept                                                                           1.7976      0.032     56.626      0.000       1.735       1.860
# C(RwJOCCSD, Treatment(reference='Retired'))[T.Farming/Forestry/Fishing]            -0.0696      0.038     -1.812      0.070      -0.145       0.006
# C(RwJOCCSD, Treatment(reference='Retired'))[T.Food/Personal/Service]                0.0122      0.018      0.663      0.507      -0.024       0.048
# C(RwJOCCSD, Treatment(reference='Retired'))[T.Healthcare]                           0.1709      0.032      5.268      0.000       0.107       0.234
# C(RwJOCCSD, Treatment(reference='Retired'))[T.High Risk Occupations]                0.0394      0.047      0.847      0.397      -0.052       0.131
# C(RwJOCCSD, Treatment(reference='Retired'))[T.Management/Clerical/Business]         0.2419      0.013     18.433      0.000       0.216       0.268
# C(RwJOCCSD, Treatment(reference='Retired'))[T.STEM/Professional/Technical]          0.3678      0.017     21.057      0.000       0.334       0.402
# C(RwJOCCSD, Treatment(reference='Retired'))[T.Sales]                                0.2259      0.021     10.931      0.000       0.185       0.266
# C(RwJOCCSD, Treatment(reference='Retired'))[T.Skilled Trades/Production/Manual]    -0.1034      0.016     -6.483      0.000      -0.135      -0.072
# RwAGEM_B                                                                           -0.0296      0.000    -65.331      0.000      -0.031      -0.029
# ==============================================================================
# Skew:                          0.0670   Kurtosis:                      -0.0097
# Centered skew:                 0.0088   Centered kurtosis:              1.1425
# ==============================================================================

# %% [markdown]
# ### 1.2 Test VIF Calculation

# %%
# print(resultsExch.model.exog[1:6,:])
# print(len(resultsExch.model.exog_names))
# print(resultsExch.model.exog.shape)

# print(X_design_df)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
import patsy

X_mat = resultsExch.model.exog
X_names = resultsExch.model.exog_names
X_design_df = pd.DataFrame(X_mat, columns = X_names)
print("Design Matrix (X) columns:", X_design_df.columns.tolist())

vif_threshold = 10

# intercept_column_name = 'Intercept' # Default name by patsy/statsmodels
# if intercept_column_name in X_design_df.columns:
#     X_for_vif = X_design_df.drop(intercept_column_name, axis=1)
#     print(f"Dropped '{intercept_column_name}' for VIF calculation.")
# else:
#     print(f"Warning: Could not find column named '{intercept_column_name}' to drop for VIF.")

vif_data = pd.DataFrame()
vif_data["features"] = X_design_df.columns
vif_data["VIF"] = [variance_inflation_factor(X_design_df.values, i) for i in range(X_design_df.shape[1])]

print(vif_data)
# Out:
# Design Matrix (X) columns: ['Intercept', "C(RwJOCCSD, Treatment(reference='Retired'))[T.Farming/Forestry/Fishing]", "C(RwJOCCSD, Treatment(reference='Retired'))[T.Food/Personal/Service]", "C(RwJOCCSD, Treatment(reference='Retired'))[T.Healthcare]", "C(RwJOCCSD, Treatment(reference='Retired'))[T.High Risk Occupations]", "C(RwJOCCSD, Treatment(reference='Retired'))[T.Management/Clerical/Business]", "C(RwJOCCSD, Treatment(reference='Retired'))[T.STEM/Professional/Technical]", "C(RwJOCCSD, Treatment(reference='Retired'))[T.Sales]", "C(RwJOCCSD, Treatment(reference='Retired'))[T.Skilled Trades/Production/Manual]", 'RwAGEM_B']
#                                             features        VIF
# 0                                          Intercept  81.368272
# 1  C(RwJOCCSD, Treatment(reference='Retired'))[T....   1.005279
# 2  C(RwJOCCSD, Treatment(reference='Retired'))[T....   1.033572
# 3  C(RwJOCCSD, Treatment(reference='Retired'))[T....   1.012888
# 4  C(RwJOCCSD, Treatment(reference='Retired'))[T....   1.005737
# 5  C(RwJOCCSD, Treatment(reference='Retired'))[T....   1.069916
# 6  C(RwJOCCSD, Treatment(reference='Retired'))[T....   1.038652
# 7  C(RwJOCCSD, Treatment(reference='Retired'))[T....   1.023733
# 8  C(RwJOCCSD, Treatment(reference='Retired'))[T....   1.057654
# 9                                           RwAGEM_B   1.163378

# %%
import re

# [var for var in indepVars if var not in df.columns.to_list()]
# Extract the string that precedes '[T.' in the given variable name
# var_name = 'RwLIVBRO'
# match = re.match(r"(.+)\[T\.", var_name)
# print(match)
# if match:
#     preceding_str = match.group(1)
#     print(preceding_str)
# else:
#     print("No match found.")


indepVars = [
    'RwAGEM_B', "RwJOCCSD",
    'RwJHOURS', 'RwWGIHR']

indepVars.remove('RwAGEM_B')
print(indepVars)
# Out:
# ['RwJOCCSD', 'RwJHOURS', 'RwWGIHR']

# %%
def vif_elimination(df, indepVars, depVar, varsToKeep, threshold):
    ''' 
    Calculate variance inflation factor (VIF) of each independent variables, 
    Remove those with VIF that exceed the threshold

    Returns:
    A list of variables whose VIF are less than the pre-specified threshold
    '''
    from statsmodels.stats.outliers_influence import variance_inflation_factor
    import patsy
    
    X_design_df = patsy.dmatrices(
                formula_like = depVar + "~" + ' + '.join(indepVars),
                data = df, 
                return_type="dataframe")[1]
    
    columns_to_keep = []
    for var in varsToKeep:
        # For categorical variables, patsy expands them with "C(var, ...)[T.level]" or similar
        # So we check if the column name starts with the variable name or matches exactly
        columns_to_keep.extend([col for col in X_design_df.columns if col == var or col.startswith(f"C({var},") or col.startswith(f"{var}[T.")])
    print("Columns to be kept for indepVars:", columns_to_keep)

    multicolinear = True

    while multicolinear:

        ## Calculate VIF for each variable and dummy variable
        vif_data = pd.DataFrame()
        vif_data["features"] = X_design_df.columns
        vif_data["VIF"] = [variance_inflation_factor(X_design_df.values, i) for i in range(X_design_df.shape[1])]
        

        vif_data.set_index("features", inplace=True)
        # print(vif_data)
        ## Sort variables by VIF values, accept for variables to keep
        vif_ranking = vif_data.drop(index= columns_to_keep, axis = 0).sort_values(by = "VIF", ascending=False)
        # print(vif_ranking)
        ## Isolate the variable with the highest variance
        inflatorIdx = vif_ranking.index[0]
        # print(inflatorIdx)
        # print(vif_ranking.iloc[0, 0] <= threshold)
        if vif_ranking.iloc[0, 0] >= threshold:
            ## Get inflator variable full name
            # print(inflatorIdx)
            
            ## Get the truncated name
            try:
                match = re.match(r"(.+)\[T\.", inflatorIdx)
                varInflator = match.group(1)
                indepVars.remove(varInflator)
                print(f"Removed {varInflator}")
            except:
                print("Fine, not > 2 categorical values")
                ## Remove the top inflator above the threshold
                indepVars.remove(inflatorIdx)
                print(f"Removed {inflatorIdx}")

            ## Update design matrix
            # Get the list of column names in the design matrix that correspond to indepVars (including expanded categorical variables)
            # This will match the base variable name or its dummy expansion
            X_design_df = patsy.dmatrices(
                formula_like = depVar + "~" + ' + '.join(indepVars),
                data = df, 
                return_type="dataframe")[1]
            print(f"Current predictor list: {indepVars}")
        else:
            print("All VIFs are under the threshold!")
            break

    print(vif_ranking)
    return indepVars

test_df = df.head(500)
indepVars = [
    'RwAGEM_B', "RwJOCCSD",
    'RwJHOURS', 'RwWGIHR',
    'RwJPHYS',  'RwJSTRES', 'RwJSIGHT', 'RwCENREG',
    'RwMSTAT', 'RwLIVBRO', 'RwHIBP', 'RwDIAB', 'RwCANCR',
    'RwLUNG', 'RwHEART', 'RwSTROK', 'RwPSYCH', 'RwVIGACT', 'RwSMOKEV',
    'RwDRINK', 'RwPhyLim', 'RwCogLim', 'RwJLIFT', 'RwJSTOOP',
    # 'RwLOST', 'RwWANDER', 'RwHALUC', 'RwALONE', 'RwAnyCogImp', 
    'HwATOTB', 
    'HwADEBT', 'HwACHCK','HwAMRTB', 'HwITOT', 
    'RAGENDER', 'RARACEM', 'RAEDYRS', 'RAEVBRN']
depVar = "RwTR20"
varsToKeep = ['Intercept', 'RwAGEM_B', "RwJOCCSD", "RAEDYRS"]
resultVars = vif_elimination(df, indepVars, depVar, varsToKeep, 5)
print(resultVars)
# Out:
# Columns to be kept for indepVars: ['Intercept', 'RwAGEM_B', 'RwJOCCSD[T.Food/Personal/Service]', 'RwJOCCSD[T.Healthcare]', 'RwJOCCSD[T.High Risk Occupations]', 'RwJOCCSD[T.Management/Clerical/Business]', 'RwJOCCSD[T.Retired]', 'RwJOCCSD[T.STEM/Professional/Technical]', 'RwJOCCSD[T.Sales]', 'RwJOCCSD[T.Skilled Trades/Production/Manual]', 'RAEDYRS']
# C:\Users\86139\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\statsmodels\regression\linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# All VIFs are under the threshold!
#                         VIF
# features
# HwATOTB            1.754046
# HwITOT             1.598110
# RwJPHYS            1.552152
# HwACHCK            1.541683
# RAGENDER[T.M]      1.493098
# RARACEM[T.White]   1.483961
# RwJSTOOP           1.462164
# RwJLIFT            1.444136
# RwJHOURS           1.344055
# RARACEM[T.Others]  1.326010
# RwMSTAT            1.323283
# RwJSTRES           1.206301
# RwCogLim[T.True]   1.143392
# RwDRINK            1.125985
# RwSMOKEV           1.110009
# RwHEART            1.105007
# RAEVBRN            1.094125
# RwHIBP             1.093638
# RwDIAB             1.076150
# RwPhyLim[T.True]   1.074567
# RwLIVBRO[T.3--8]   1.062533
# RwPSYCH            1.062398
# RwVIGACT           1.058559
# RwLUNG             1.053380
# RwJSIGHT           1.048367
# HwADEBT            1.043102
# RwSTROK            1.039314
# RwCANCR            1.037396
# HwAMRTB            1.036789
# RwCENREG           1.033807
# RwLIVBRO[T.9--14]  1.019082
# RwWGIHR            1.009383
# ['RwAGEM_B', 'RwJOCCSD', 'RwJHOURS', 'RwWGIHR', 'RwJPHYS', 'RwJSTRES', 'RwJSIGHT', 'RwCENREG', 'RwMSTAT', 'RwLIVBRO', 'RwHIBP', 'RwDIAB', 'RwCANCR', 'RwLUNG', 'RwHEART', 'RwSTROK', 'RwPSYCH', 'RwVIGACT', 'RwSMOKEV', 'RwDRINK', 'RwPhyLim', 'RwCogLim', 'RwJLIFT', 'RwJSTOOP', 'HwATOTB', 'HwADEBT', 'HwACHCK', 'HwAMRTB', 'HwITOT', 'RAGENDER', 'RARACEM', 'RAEDYRS', 'RAEVBRN']

# %%
cols = [
    "RwJLIFT", "RwJSTOOP", "RwLUNG", "RwAnyCogImp",
    "RwLOST", "RwWANDER", "RwHALUC", "RwALONE", "HwADEBT"
]
missing_pct =df[cols].isna().mean() * 100
print(missing_pct)
# Out:
# RwJLIFT        80.653706
# RwJSTOOP       80.660274
# RwLUNG          0.000000
# RwAnyCogImp     0.000000
# RwLOST          0.000000
# RwWANDER        0.000000
# RwHALUC         0.000000
# RwALONE         0.000000
# HwADEBT         0.000000
# dtype: float64

# %% [markdown]
# ## 2. Variable Selection by QIC:

# %%
# Calculate QIC for each model as a measure of goodness of fit
def calc_qic(model_result):
    # QIC = -2 * quasi-likelihood + 2 * trace(V_hat^-1 * V_model)
    # statsmodels does not provide QIC directly, but we can use qic() if available
    try:
        return model_result.qic()[0]
    except AttributeError:
        return np.nan

qic_exch = calc_qic(resultsExch)
qic_ar = calc_qic(resultsAR)
qic_indep = calc_qic(resultsIndep)

print(f"QIC (Exchangeable): {qic_exch}")
print(f"QIC (Autoregressive): {qic_ar}")
print(f"QIC (Unstructured): {qic_indep}")

# The base model with independence covariance structure yields the lowest QIC, marking the best performing base model.
# Out:
# C:\Users\86139\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\statsmodels\genmod\generalized_estimating_equations.py:1934: UserWarning: QIC values obtained using scale=None are not appropriate for comparing models
#   warnings.warn("QIC values obtained using scale=None are not "
# QIC (Exchangeable): 10289.840917145659
# QIC (Autoregressive): 10285.401940937447
# QIC (Unstructured): 10120.574391687638

# %%
import gc
gc.collect()
# Out:
# 0

# %%
fullFormula
# Out:
# "RwRecProp ~ RwAGEM_B + RAEDYRS + C(RwJOCCSD, Treatment(reference='Retired')) + RwCENREG + RwLUNG + RARACEM + RwJLIFT + RwPhyLim + RAEVBRN + RwSMOKEV + RwJPHYS + RwJHOURS + RwLIVBRO + RwJSIGHT + RwDRINK + RwCogLim + RwMSTAT + RwSTROK + RwCANCR + RwJSTRES + HwITOT + RAGENDER + RwHIBP + RwWGIHR + RwJSTOOP + HwAMRTB + HwACHCK + RwVIGACT + HwATOTB + RwPSYCH + HwADEBT + RwDIAB + RwHEART"

# %%
import re
import numpy as np

def stepwise_selection_qic_forward(data, groups, cov_struct, family, start_formula, end_formula, verbose=True, qic_threshold=0):
    """
    Perform forward feature selection based on QIC for GEE models.

    Parameters:
        data: pandas.DataFrame
            The dataset containing all variables used in the formulas.
        groups: array-like
            Grouping variable for GEE (e.g., subject or cluster IDs).
        cov_struct: statsmodels.genmod.cov_struct.CovStruct
            Covariance structure for GEE (e.g., Exchangeable, Autoregressive).
        family: statsmodels.genmod.families.Family
            The family object for GEE (e.g., Gaussian, Binomial).
        start_formula: str
            The starting model formula (patsy syntax).
        end_formula: str
            The full model formula (patsy syntax, includes all candidate variables).
        verbose: bool, optional
            If True, prints progress at each step.
        qic_threshold: float, optional
            Minimum QIC improvement required to continue selection.

    Returns:
        best_formula: str, formula of the best model found
        best_result: fitted GEE result object
        history: list of (formula, QIC)
    """
    import statsmodels.formula.api as smf

    def get_terms(formula):
        rhs = formula.split('~')[1]
        terms = [t.strip() for t in re.split(r'\s*\+\s*', rhs) if t.strip() != '']
        terms = [t for t in terms if t != '1']
        return set(terms)

    def build_formula(lhs, terms):
        if not terms:
            return f"{lhs} ~ 1"
        return f"{lhs} ~ {' + '.join(sorted(terms))}"

    def calc_qic(result):
        try:
            return result.qic(scale=1)[0]
        except Exception:
            return np.nan

    lhs = start_formula.split('~')[0].strip()
    start_terms = get_terms(start_formula)
    end_terms = get_terms(end_formula)
    current_terms = set(start_terms)
    history = []

    # Fit initial model
    current_formula = build_formula(lhs, current_terms)
    model = smf.gee(current_formula, groups=groups, data=data, cov_struct=cov_struct, family=family)
    result = model.fit(cov_type="robust")
    best_qic = calc_qic(result)
    best_formula = current_formula
    best_result = result
    history.append((current_formula, best_qic))

    improved = True
    while improved:
        improved = False
        qic_candidates = []
        formulas = []
        term_changes = []
        for term in sorted(end_terms - current_terms):
            new_terms = current_terms | {term}
            formula = build_formula(lhs, new_terms)
            try:
                model = smf.gee(formula, groups=groups, data=data, cov_struct=cov_struct, family=family)
                result = model.fit(cov_type="robust")
                qic = calc_qic(result)
            except Exception:
                qic = np.nan
            qic_candidates.append(qic)
            formulas.append(formula)
            term_changes.append(('add', term))

            print(f"Candidate Term: {term}\n")
            print(f"Candidate Term's QIC: {qic}\n")
            print(f"Candidate formula: {formula}\n")

            

        if qic_candidates:
            if np.all(np.isnan(qic_candidates)):
                if verbose:
                    print("All QIC candidates are NaN, stopping.")
                break
            min_idx = np.nanargmin(qic_candidates)
            min_qic = qic_candidates[min_idx]
            if (best_qic - min_qic) > qic_threshold:
                improved = True
                best_qic = min_qic
                best_formula = formulas[min_idx]
                action, term = term_changes[min_idx]
                
                current_terms.add(term)
                history.append((best_formula, best_qic))
                
                if verbose:
                    print(f"Step: {action}, QIC: {best_qic:.2f}, Formula: {best_formula}")
            else:
                if verbose:
                    print("No QIC improvement above threshold, stopping.")
        else:
            if verbose:
                print("No candidates left, stopping.")
    
    model = smf.gee(best_formula, groups=groups, data=data, cov_struct=cov_struct, family=family)
    best_result = model.fit(cov_type="robust")
    return best_formula, best_result, history

# %%
controlVars = set(resultVars)
controlVars = controlVars - set(['RwAGEM_B', 'RwJOCCSD', 'RAEDYRS'])

baseFormula = "RwRecProp ~ RwAGEM_B + RAEDYRS + C(RwJOCCSD, Treatment(reference='Retired'))"
fullFormula = baseFormula +  ' + ' + ' + '.join(controlVars)
# Out:
# 465.0

# %%
exchangeable_corr = sm.cov_struct.Exchangeable()
bestExchForm, bestExchResult, ExchHistory =\
    stepwise_selection_qic_forward(df, df["HHIDPN"], exchangeable_corr, 
                        sm.families.Binomial(), 
                        baseFormula, fullFormula, 
                        verbose=True, 
                        qic_threshold=10)

# bestARForm, bestARResult, ARHistory =\
#     stepwise_selection_qic_forward(df, df["HHIDPN"], autoregress_corr, 
#                         sm.families.Binomial(), 
#                         baseFormula, fullFormula, 
#                         verbose=True, 
#                         qic_threshold=10)

# bestIndepForm, bestIndepResult, IndepHistory =\
#     stepwise_selection_qic_forward(df, df["HHIDPN"], indep_corr, 
#                         sm.families.Binomial(), 
#                         baseFormula, fullFormula, 
#                         verbose=False, 
#                         qic_threshold=10)
# Out:
# Candidate Term: HwACHCK
#
# Candidate Term's QIC: 9165.966348275875
#
# Candidate formula: RwRecProp ~ C(RwJOCCSD, Treatment(reference='Retired')) + HwACHCK + RAEDYRS + RwAGEM_B
#
# Candidate Term: HwADEBT
#
# Candidate Term's QIC: 9319.731277866787
#
# Candidate formula: RwRecProp ~ C(RwJOCCSD, Treatment(reference='Retired')) + HwADEBT + RAEDYRS + RwAGEM_B
#
# Candidate Term: HwAMRTB
#
# Candidate Term's QIC: 9318.416394591974
#
# Candidate formula: RwRecProp ~ C(RwJOCCSD, Treatment(reference='Retired')) + HwAMRTB + RAEDYRS + RwAGEM_B
#
# Candidate Term: HwATOTB
#
# Candidate Term's QIC: 8796.45196097415
#
# Candidate formula: RwRecProp ~ C(RwJOCCSD, Treatment(reference='Retired')) + HwATOTB + RAEDYRS + RwAGEM_B
#
# Candidate Term: HwITOT
#
# Candidate Term's QIC: 9259.990945258314
#
# Candidate formula: RwRecProp ~ C(RwJOCCSD, Treatment(reference='Retired')) + HwITOT + RAEDYRS + RwAGEM_B
#
# Candidate Term: RAEVBRN
#
# Candidate Term's QIC: 9296.852687156708
#
# Candidate formula: RwRecProp ~ C(RwJOCCSD, Treatment(reference='Retired')) + RAEDYRS + RAEVBRN + RwAGEM_B
#
# Candidate Term: RAGENDER
#
# Candidate Term's QIC: 9063.731021213782
#
# Candidate formula: RwRecProp ~ C(RwJOCCSD, Treatment(reference='Retired')) + RAEDYRS + RAGENDER + RwAGEM_B
#
# Candidate Term: RARACEM
#
# Candidate Term's QIC: 9117.564553081314
#
# Candidate formula: RwRecProp ~ C(RwJOCCSD, Treatment(reference='Retired')) + RAEDYRS + RARACEM + RwAGEM_B
#
# Candidate Term: RwCANCR
#
# Candidate Term's QIC: 9312.882265994805
#
# Candidate formula: RwRecProp ~ C(RwJOCCSD, Treatment(reference='Retired')) + RAEDYRS + RwAGEM_B + RwCANCR
#
# Candidate Term: RwCENREG
#
# Candidate Term's QIC: 9319.921046232486
#
# Candidate formula: RwRecProp ~ C(RwJOCCSD, Treatment(reference='Retired')) + RAEDYRS + RwAGEM_B + RwCENREG
#
# Candidate Term: RwCogLim
#
# Candidate Term's QIC: 9152.07907329258
#
# Candidate formula: RwRecProp ~ C(RwJOCCSD, Treatment(reference='Retired')) + RAEDYRS + RwAGEM_B + RwCogLim
#
# Candidate Term: RwDIAB
#
# Candidate Term's QIC: 9262.718969268593
#
# Candidate formula: RwRecProp ~ C(RwJOCCSD, Treatment(reference='Retired')) + RAEDYRS + RwAGEM_B + RwDIAB
#
# Candidate Term: RwDRINK
#
# Candidate Term's QIC: 9288.109373593546
#
# Candidate formula: RwRecProp ~ C(RwJOCCSD, Treatment(reference='Retired')) + RAEDYRS + RwAGEM_B + RwDRINK
#
# Candidate Term: RwHEART
#
# Candidate Term's QIC: 9303.444651825195
#
# Candidate formula: RwRecProp ~ C(RwJOCCSD, Treatment(reference='Retired')) + RAEDYRS + RwAGEM_B + RwHEART
#
# Candidate Term: RwHIBP
#
# Candidate Term's QIC: 9311.369189295716
#
# Candidate formula: RwRecProp ~ C(RwJOCCSD, Treatment(reference='Retired')) + RAEDYRS + RwAGEM_B + RwHIBP
#
# Candidate Term: RwJHOURS
#
# Candidate Term's QIC: 1771.4722224328189
#
# Candidate formula: RwRecProp ~ C(RwJOCCSD, Treatment(reference='Retired')) + RAEDYRS + RwAGEM_B + RwJHOURS
#
# Candidate Term: RwJLIFT
#
# Candidate Term's QIC: 1778.5497258902585
#
# Candidate formula: RwRecProp ~ C(RwJOCCSD, Treatment(reference='Retired')) + RAEDYRS + RwAGEM_B + RwJLIFT
#
# Candidate Term: RwJOCCSD
#
# Candidate Term's QIC: 9319.666956550236
#
# Candidate formula: RwRecProp ~ C(RwJOCCSD, Treatment(reference='Retired')) + RAEDYRS + RwAGEM_B + RwJOCCSD
#
# Candidate Term: RwJPHYS
#
# Candidate Term's QIC: 1776.950053195554
#
# Candidate formula: RwRecProp ~ C(RwJOCCSD, Treatment(reference='Retired')) + RAEDYRS + RwAGEM_B + RwJPHYS
#
# Candidate Term: RwJSIGHT
#
# Candidate Term's QIC: 1795.1588668912827
#
# Candidate formula: RwRecProp ~ C(RwJOCCSD, Treatment(reference='Retired')) + RAEDYRS + RwAGEM_B + RwJSIGHT
#
# Candidate Term: RwJSTOOP
#
# Candidate Term's QIC: 1773.9060584870872
#
# Candidate formula: RwRecProp ~ C(RwJOCCSD, Treatment(reference='Retired')) + RAEDYRS + RwAGEM_B + RwJSTOOP
#
# Candidate Term: RwJSTRES
#
# Candidate Term's QIC: 1803.0782487480187
#
# Candidate formula: RwRecProp ~ C(RwJOCCSD, Treatment(reference='Retired')) + RAEDYRS + RwAGEM_B + RwJSTRES
#
# Candidate Term: RwLIVBRO
#
# Candidate Term's QIC: 9314.476265441066
#
# Candidate formula: RwRecProp ~ C(RwJOCCSD, Treatment(reference='Retired')) + RAEDYRS + RwAGEM_B + RwLIVBRO
#
# Candidate Term: RwLUNG
#
# Candidate Term's QIC: 9318.840130663393
#
# Candidate formula: RwRecProp ~ C(RwJOCCSD, Treatment(reference='Retired')) + RAEDYRS + RwAGEM_B + RwLUNG
#
# Candidate Term: RwMSTAT
#
# Candidate Term's QIC: 9313.623014843195
#
# Candidate formula: RwRecProp ~ C(RwJOCCSD, Treatment(reference='Retired')) + RAEDYRS + RwAGEM_B + RwMSTAT
#
# Candidate Term: RwPSYCH
#
# Candidate Term's QIC: 9293.059382862417
#
# Candidate formula: RwRecProp ~ C(RwJOCCSD, Treatment(reference='Retired')) + RAEDYRS + RwAGEM_B + RwPSYCH
#
# Candidate Term: RwPhyLim
#
# Candidate Term's QIC: 9166.356449108296
#
# Candidate formula: RwRecProp ~ C(RwJOCCSD, Treatment(reference='Retired')) + RAEDYRS + RwAGEM_B + RwPhyLim
#
# Candidate Term: RwSMOKEV
#
# Candidate Term's QIC: 9225.975808114312
#
# Candidate formula: RwRecProp ~ C(RwJOCCSD, Treatment(reference='Retired')) + RAEDYRS + RwAGEM_B + RwSMOKEV
#
# Candidate Term: RwSTROK
#
# Candidate Term's QIC: 9246.325088634543
#
# Candidate formula: RwRecProp ~ C(RwJOCCSD, Treatment(reference='Retired')) + RAEDYRS + RwAGEM_B + RwSTROK
#
# Candidate Term: RwVIGACT
#
# Candidate Term's QIC: 9319.554893083869
#
# Candidate formula: RwRecProp ~ C(RwJOCCSD, Treatment(reference='Retired')) + RAEDYRS + RwAGEM_B + RwVIGACT
#
# Candidate Term: RwWGIHR
#
# Candidate Term's QIC: 1523.752564353177
#
# Candidate formula: RwRecProp ~ C(RwJOCCSD, Treatment(reference='Retired')) + RAEDYRS + RwAGEM_B + RwWGIHR
#
# Step: add, QIC: 1523.75, Formula: RwRecProp ~ C(RwJOCCSD, Treatment(reference='Retired')) + RAEDYRS + RwAGEM_B + RwWGIHR
# Candidate Term: HwACHCK
#
# Candidate Term's QIC: 1508.5487940131013
#
# Candidate formula: RwRecProp ~ C(RwJOCCSD, Treatment(reference='Retired')) + HwACHCK + RAEDYRS + RwAGEM_B + RwWGIHR
#
# Candidate Term: HwADEBT
#
# Candidate Term's QIC: 1523.620871432005
#
# Candidate formula: RwRecProp ~ C(RwJOCCSD, Treatment(reference='Retired')) + HwADEBT + RAEDYRS + RwAGEM_B + RwWGIHR
#
# Candidate Term: HwAMRTB
#
# Candidate Term's QIC: 1523.6309735581983
#
# Candidate formula: RwRecProp ~ C(RwJOCCSD, Treatment(reference='Retired')) + HwAMRTB + RAEDYRS + RwAGEM_B + RwWGIHR
#
# Candidate Term: HwATOTB
#
# Candidate Term's QIC: 1436.9645068459902
#
# Candidate formula: RwRecProp ~ C(RwJOCCSD, Treatment(reference='Retired')) + HwATOTB + RAEDYRS + RwAGEM_B + RwWGIHR
#
# Candidate Term: HwITOT
#
# Candidate Term's QIC: 1520.8432880353453
#
# Candidate formula: RwRecProp ~ C(RwJOCCSD, Treatment(reference='Retired')) + HwITOT + RAEDYRS + RwAGEM_B + RwWGIHR
#
# Candidate Term: RAEVBRN
#
# Candidate Term's QIC: 1520.992562254201
#
# Candidate formula: RwRecProp ~ C(RwJOCCSD, Treatment(reference='Retired')) + RAEDYRS + RAEVBRN + RwAGEM_B + RwWGIHR
#
# Candidate Term: RAGENDER
#
# Candidate Term's QIC: 1478.943239672619
#
# Candidate formula: RwRecProp ~ C(RwJOCCSD, Treatment(reference='Retired')) + RAEDYRS + RAGENDER + RwAGEM_B + RwWGIHR
#
# Candidate Term: RARACEM
#
# Candidate Term's QIC: 1494.8792158167914
#
# Candidate formula: RwRecProp ~ C(RwJOCCSD, Treatment(reference='Retired')) + RAEDYRS + RARACEM + RwAGEM_B + RwWGIHR
#
# Candidate Term: RwCANCR
#
# Candidate Term's QIC: 1523.1303325111173
#
# Candidate formula: RwRecProp ~ C(RwJOCCSD, Treatment(reference='Retired')) + RAEDYRS + RwAGEM_B + RwCANCR + RwWGIHR
#
# Candidate Term: RwCENREG
#
# Candidate Term's QIC: 1523.814665616518
#
# Candidate formula: RwRecProp ~ C(RwJOCCSD, Treatment(reference='Retired')) + RAEDYRS + RwAGEM_B + RwCENREG + RwWGIHR
#
# Candidate Term: RwCogLim
#
# Candidate Term's QIC: 1517.851626384181
#
# Candidate formula: RwRecProp ~ C(RwJOCCSD, Treatment(reference='Retired')) + RAEDYRS + RwAGEM_B + RwCogLim + RwWGIHR
#
# Candidate Term: RwDIAB
#
# Candidate Term's QIC: 1515.5259794744252
#
# Candidate formula: RwRecProp ~ C(RwJOCCSD, Treatment(reference='Retired')) + RAEDYRS + RwAGEM_B + RwDIAB + RwWGIHR
#
# Candidate Term: RwDRINK
#
# Candidate Term's QIC: 1522.7611700565105
#
# Candidate formula: RwRecProp ~ C(RwJOCCSD, Treatment(reference='Retired')) + RAEDYRS + RwAGEM_B + RwDRINK + RwWGIHR
#
# Candidate Term: RwHEART
#
# Candidate Term's QIC: 1521.883901018378
#
# Candidate formula: RwRecProp ~ C(RwJOCCSD, Treatment(reference='Retired')) + RAEDYRS + RwAGEM_B + RwHEART + RwWGIHR
#
# Candidate Term: RwHIBP
#
# Candidate Term's QIC: 1521.8151836124928
#
# Candidate formula: RwRecProp ~ C(RwJOCCSD, Treatment(reference='Retired')) + RAEDYRS + RwAGEM_B + RwHIBP + RwWGIHR
#
# Candidate Term: RwJHOURS
#
# Candidate Term's QIC: 1420.6188994823174
#
# Candidate formula: RwRecProp ~ C(RwJOCCSD, Treatment(reference='Retired')) + RAEDYRS + RwAGEM_B + RwJHOURS + RwWGIHR
#
# Candidate Term: RwJLIFT
#
# Candidate Term's QIC: 1395.5343890658166
#
# Candidate formula: RwRecProp ~ C(RwJOCCSD, Treatment(reference='Retired')) + RAEDYRS + RwAGEM_B + RwJLIFT + RwWGIHR
# C:\Users\86139\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\statsmodels\genmod\generalized_estimating_equations.py:1300: IterationLimitWarning: Iteration limit reached prior to convergence
#   warnings.warn("Iteration limit reached prior to convergence",
# Candidate Term: RwJOCCSD
#
# Candidate Term's QIC: -144338.8861388969
#
# Candidate formula: RwRecProp ~ C(RwJOCCSD, Treatment(reference='Retired')) + RAEDYRS + RwAGEM_B + RwJOCCSD + RwWGIHR
#
# Candidate Term: RwJPHYS
#
# Candidate Term's QIC: 1394.4168754699424
#
# Candidate formula: RwRecProp ~ C(RwJOCCSD, Treatment(reference='Retired')) + RAEDYRS + RwAGEM_B + RwJPHYS + RwWGIHR
#
# Candidate Term: RwJSIGHT
#
# Candidate Term's QIC: 1401.7289885543196
#
# Candidate formula: RwRecProp ~ C(RwJOCCSD, Treatment(reference='Retired')) + RAEDYRS + RwAGEM_B + RwJSIGHT + RwWGIHR
#
# Candidate Term: RwJSTOOP
#
# Candidate Term's QIC: 1395.0656155753152
#
# Candidate formula: RwRecProp ~ C(RwJOCCSD, Treatment(reference='Retired')) + RAEDYRS + RwAGEM_B + RwJSTOOP + RwWGIHR
#
# Candidate Term: RwJSTRES
#
# Candidate Term's QIC: 1413.6355663132515
#
# Candidate formula: RwRecProp ~ C(RwJOCCSD, Treatment(reference='Retired')) + RAEDYRS + RwAGEM_B + RwJSTRES + RwWGIHR
#
# Candidate Term: RwLIVBRO
#
# Candidate Term's QIC: 1521.452981799016
#
# Candidate formula: RwRecProp ~ C(RwJOCCSD, Treatment(reference='Retired')) + RAEDYRS + RwAGEM_B + RwLIVBRO + RwWGIHR
#
# Candidate Term: RwLUNG
#
# Candidate Term's QIC: 1523.3408508014018
#
# Candidate formula: RwRecProp ~ C(RwJOCCSD, Treatment(reference='Retired')) + RAEDYRS + RwAGEM_B + RwLUNG + RwWGIHR
#
# Candidate Term: RwMSTAT
#
# Candidate Term's QIC: 1522.2635143545306
#
# Candidate formula: RwRecProp ~ C(RwJOCCSD, Treatment(reference='Retired')) + RAEDYRS + RwAGEM_B + RwMSTAT + RwWGIHR
#
# Candidate Term: RwPSYCH
#
# Candidate Term's QIC: 1523.2873345114235
#
# Candidate formula: RwRecProp ~ C(RwJOCCSD, Treatment(reference='Retired')) + RAEDYRS + RwAGEM_B + RwPSYCH + RwWGIHR
#
# Candidate Term: RwPhyLim
#
# Candidate Term's QIC: 1518.2938246715553
#
# Candidate formula: RwRecProp ~ C(RwJOCCSD, Treatment(reference='Retired')) + RAEDYRS + RwAGEM_B + RwPhyLim + RwWGIHR
#
# Candidate Term: RwSMOKEV
#
# Candidate Term's QIC: 1516.2163096330557
#
# Candidate formula: RwRecProp ~ C(RwJOCCSD, Treatment(reference='Retired')) + RAEDYRS + RwAGEM_B + RwSMOKEV + RwWGIHR
#
# Candidate Term: RwSTROK
#
# Candidate Term's QIC: 1522.570199144255
#
# Candidate formula: RwRecProp ~ C(RwJOCCSD, Treatment(reference='Retired')) + RAEDYRS + RwAGEM_B + RwSTROK + RwWGIHR
#
# Candidate Term: RwVIGACT
#
# Candidate Term's QIC: 1522.6689636768263
#
# Candidate formula: RwRecProp ~ C(RwJOCCSD, Treatment(reference='Retired')) + RAEDYRS + RwAGEM_B + RwVIGACT + RwWGIHR
#
# Step: add, QIC: -144338.89, Formula: RwRecProp ~ C(RwJOCCSD, Treatment(reference='Retired')) + RAEDYRS + RwAGEM_B + RwJOCCSD + RwWGIHR
# Candidate Term: HwACHCK
#
# Candidate Term's QIC: 5286.704381201436
#
# Candidate formula: RwRecProp ~ C(RwJOCCSD, Treatment(reference='Retired')) + HwACHCK + RAEDYRS + RwAGEM_B + RwJOCCSD + RwWGIHR
#
# Candidate Term: HwADEBT
#
# Candidate Term's QIC: 1555.7205181027616
#
# Candidate formula: RwRecProp ~ C(RwJOCCSD, Treatment(reference='Retired')) + HwADEBT + RAEDYRS + RwAGEM_B + RwJOCCSD + RwWGIHR
# C:\Users\86139\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\statsmodels\genmod\generalized_estimating_equations.py:1300: IterationLimitWarning: Iteration limit reached prior to convergence
#   warnings.warn("Iteration limit reached prior to convergence",
# Candidate Term: HwAMRTB
#
# Candidate Term's QIC: 1569.6424648087848
#
# Candidate formula: RwRecProp ~ C(RwJOCCSD, Treatment(reference='Retired')) + HwAMRTB + RAEDYRS + RwAGEM_B + RwJOCCSD + RwWGIHR
#
# Candidate Term: HwATOTB
#
# Candidate Term's QIC: 1302.6848419570138
#
# Candidate formula: RwRecProp ~ C(RwJOCCSD, Treatment(reference='Retired')) + HwATOTB + RAEDYRS + RwAGEM_B + RwJOCCSD + RwWGIHR
#
# Candidate Term: HwITOT
#
# Candidate Term's QIC: 1535.4777353480324
#
# Candidate formula: RwRecProp ~ C(RwJOCCSD, Treatment(reference='Retired')) + HwITOT + RAEDYRS + RwAGEM_B + RwJOCCSD + RwWGIHR
# C:\Users\86139\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\statsmodels\genmod\generalized_estimating_equations.py:1300: IterationLimitWarning: Iteration limit reached prior to convergence
#   warnings.warn("Iteration limit reached prior to convergence",
# Candidate Term: RAEVBRN
#
# Candidate Term's QIC: 1480.0484738447685
#
# Candidate formula: RwRecProp ~ C(RwJOCCSD, Treatment(reference='Retired')) + RAEDYRS + RAEVBRN + RwAGEM_B + RwJOCCSD + RwWGIHR
#
# Candidate Term: RAGENDER
#
# Candidate Term's QIC: 1392.828777681813
#
# Candidate formula: RwRecProp ~ C(RwJOCCSD, Treatment(reference='Retired')) + RAEDYRS + RAGENDER + RwAGEM_B + RwJOCCSD + RwWGIHR
#
# Candidate Term: RARACEM
#
# Candidate Term's QIC: 1977.462196755634
#
# Candidate formula: RwRecProp ~ C(RwJOCCSD, Treatment(reference='Retired')) + RAEDYRS + RARACEM + RwAGEM_B + RwJOCCSD + RwWGIHR
#
# Candidate Term: RwCANCR
#
# Candidate Term's QIC: 1487.3279392904385
#
# Candidate formula: RwRecProp ~ C(RwJOCCSD, Treatment(reference='Retired')) + RAEDYRS + RwAGEM_B + RwCANCR + RwJOCCSD + RwWGIHR
#
# Candidate Term: RwCENREG
#
# Candidate Term's QIC: 2446.112624091543
#
# Candidate formula: RwRecProp ~ C(RwJOCCSD, Treatment(reference='Retired')) + RAEDYRS + RwAGEM_B + RwCENREG + RwJOCCSD + RwWGIHR
#
# Candidate Term: RwCogLim
#
# Candidate Term's QIC: 2441.761736074336
#
# Candidate formula: RwRecProp ~ C(RwJOCCSD, Treatment(reference='Retired')) + RAEDYRS + RwAGEM_B + RwCogLim + RwJOCCSD + RwWGIHR
#
# Candidate Term: RwDIAB
#
# Candidate Term's QIC: 4936.1110767202445
#
# Candidate formula: RwRecProp ~ C(RwJOCCSD, Treatment(reference='Retired')) + RAEDYRS + RwAGEM_B + RwDIAB + RwJOCCSD + RwWGIHR
# C:\Users\86139\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\statsmodels\genmod\generalized_estimating_equations.py:1300: IterationLimitWarning: Iteration limit reached prior to convergence
#   warnings.warn("Iteration limit reached prior to convergence",
# Candidate Term: RwDRINK
#
# Candidate Term's QIC: 2330.43569504728
#
# Candidate formula: RwRecProp ~ C(RwJOCCSD, Treatment(reference='Retired')) + RAEDYRS + RwAGEM_B + RwDRINK + RwJOCCSD + RwWGIHR
#
# Candidate Term: RwHEART
#
# Candidate Term's QIC: 1512.9480015730978
#
# Candidate formula: RwRecProp ~ C(RwJOCCSD, Treatment(reference='Retired')) + RAEDYRS + RwAGEM_B + RwHEART + RwJOCCSD + RwWGIHR
# C:\Users\86139\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\statsmodels\genmod\generalized_estimating_equations.py:1300: IterationLimitWarning: Iteration limit reached prior to convergence
#   warnings.warn("Iteration limit reached prior to convergence",
# Candidate Term: RwHIBP
#
# Candidate Term's QIC: 2144.461324923861
#
# Candidate formula: RwRecProp ~ C(RwJOCCSD, Treatment(reference='Retired')) + RAEDYRS + RwAGEM_B + RwHIBP + RwJOCCSD + RwWGIHR
#
# Candidate Term: RwJHOURS
#
# Candidate Term's QIC: 1420.5126698694462
#
# Candidate formula: RwRecProp ~ C(RwJOCCSD, Treatment(reference='Retired')) + RAEDYRS + RwAGEM_B + RwJHOURS + RwJOCCSD + RwWGIHR
#
# Candidate Term: RwJLIFT
#
# Candidate Term's QIC: 1395.463916881579
#
# Candidate formula: RwRecProp ~ C(RwJOCCSD, Treatment(reference='Retired')) + RAEDYRS + RwAGEM_B + RwJLIFT + RwJOCCSD + RwWGIHR
#
# Candidate Term: RwJPHYS
#
# Candidate Term's QIC: 1394.4432101097987
#
# Candidate formula: RwRecProp ~ C(RwJOCCSD, Treatment(reference='Retired')) + RAEDYRS + RwAGEM_B + RwJOCCSD + RwJPHYS + RwWGIHR
#
# Candidate Term: RwJSIGHT
#
# Candidate Term's QIC: 1404.8216768789089
#
# Candidate formula: RwRecProp ~ C(RwJOCCSD, Treatment(reference='Retired')) + RAEDYRS + RwAGEM_B + RwJOCCSD + RwJSIGHT + RwWGIHR
#
# Candidate Term: RwJSTOOP
#
# Candidate Term's QIC: 1395.0816090633375
#
# Candidate formula: RwRecProp ~ C(RwJOCCSD, Treatment(reference='Retired')) + RAEDYRS + RwAGEM_B + RwJOCCSD + RwJSTOOP + RwWGIHR
#
# Candidate Term: RwJSTRES
#
# Candidate Term's QIC: 1413.6762990953737
#
# Candidate formula: RwRecProp ~ C(RwJOCCSD, Treatment(reference='Retired')) + RAEDYRS + RwAGEM_B + RwJOCCSD + RwJSTRES + RwWGIHR
#
# Candidate Term: RwLIVBRO
#
# Candidate Term's QIC: 1792.5899654411328
#
# Candidate formula: RwRecProp ~ C(RwJOCCSD, Treatment(reference='Retired')) + RAEDYRS + RwAGEM_B + RwJOCCSD + RwLIVBRO + RwWGIHR
#
# Candidate Term: RwLUNG
#
# Candidate Term's QIC: 1538.650673425488
#
# Candidate formula: RwRecProp ~ C(RwJOCCSD, Treatment(reference='Retired')) + RAEDYRS + RwAGEM_B + RwJOCCSD + RwLUNG + RwWGIHR
#
# Candidate Term: RwMSTAT
#
# Candidate Term's QIC: 1780.1878717167037
#
# Candidate formula: RwRecProp ~ C(RwJOCCSD, Treatment(reference='Retired')) + RAEDYRS + RwAGEM_B + RwJOCCSD + RwMSTAT + RwWGIHR
#
# Candidate Term: RwPSYCH
#
# Candidate Term's QIC: -1173.038232307598
#
# Candidate formula: RwRecProp ~ C(RwJOCCSD, Treatment(reference='Retired')) + RAEDYRS + RwAGEM_B + RwJOCCSD + RwPSYCH + RwWGIHR
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[112], line 5
#       1 baseFormula = "RwRecProp ~ RwAGEM_B + RAEDYRS + C(RwJOCCSD, Treatment(reference='Retired'))"
#       2 fullFormula = 'RwRecProp ~ ' + ' + '.join(resultVars)
#       4 bestExchForm, bestExchResult, ExchHistory =\
# ----> 5     stepwise_selection_qic_forward(df, df["HHIDPN"], exchangeable_corr,
#       6                         sm.families.Binomial(),
#       7                         baseFormula, fullFormula,
#       8                         verbose=True,
#       9                         qic_threshold=10)
#      11 # bestARForm, bestARResult, ARHistory =\
#      12 #     stepwise_selection_qic_forward(df, df["HHIDPN"], autoregress_corr,
#      13 #                         sm.families.Binomial(),
#    (...)     22 #                         verbose=False,
#      23 #                         qic_threshold=10)
#
# Cell In[111], line 76, in stepwise_selection_qic_forward(data, groups, cov_struct, family, start_formula, end_formula, verbose, qic_threshold)
#      74 try:
#      75     model = smf.gee(formula, groups=groups, data=data, cov_struct=cov_struct, family=family)
# ---> 76     result = model.fit(cov_type="robust")
#      77     qic = calc_qic(result)
#      78 except Exception:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\statsmodels\genmod\generalized_estimating_equations.py:1270, in GEE.fit(self, maxiter, ctol, start_params, params_niter, first_dep_update, cov_type, ddof_scale, scaling_factor, scale)
#    1267 num_assoc_updates = 0
#    1268 for itr in range(maxiter):
# -> 1270     update, score = self._update_mean_params()
#    1271     if update is None:
#    1272         warnings.warn("Singular matrix encountered in GEE update",
#    1273                       ConvergenceWarning)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\statsmodels\genmod\generalized_estimating_equations.py:1068, in GEE._update_mean_params(self)
#    1065     vinv_d, vinv_resid = tuple(rslt)
#    1067     bmat += np.dot(dmat.T, vinv_d)
# -> 1068     score += np.dot(dmat.T, vinv_resid)
#    1070 try:
#    1071     update = np.linalg.solve(bmat, score)
#
# KeyboardInterrupt:

# %%
autoregress_corr = sm.cov_struct.Autoregressive()
bestARForm, bestARResult, ARHistory =\
    stepwise_selection_qic_forward(df, df["HHIDPN"], autoregress_corr, 
                        sm.families.Binomial(), 
                        baseFormula, fullFormula, 
                        verbose=True, 
                        qic_threshold=10)
indep_corr = sm.cov_struct.Independence()
bestIndepForm, bestIndepResult, IndepHistory =\
    stepwise_selection_qic_forward(df, df["HHIDPN"], indep_corr, 
                        sm.families.Binomial(), 
                        baseFormula, fullFormula, 
                        verbose=False, 
                        qic_threshold=10)
# Out:
# C:\Users\86139\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\statsmodels\genmod\cov_struct.py:796: FutureWarning: grid=True will become default in a future version
#   warnings.warn(
# C:\Users\86139\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\statsmodels\genmod\generalized_estimating_equations.py:1300: IterationLimitWarning: Iteration limit reached prior to convergence
#   warnings.warn("Iteration limit reached prior to convergence",
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[117], line 3
#       1 autoregress_corr = sm.cov_struct.Autoregressive()
#       2 bestARForm, bestARResult, ARHistory =\
# ----> 3     stepwise_selection_qic_forward(df, df["HHIDPN"], autoregress_corr,
#       4                         sm.families.Binomial(),
#       5                         baseFormula, fullFormula,
#       6                         verbose=True,
#       7                         qic_threshold=10)
#       8 indep_corr = sm.cov_struct.Independence()
#       9 bestIndepForm, bestIndepResult, IndepHistory =\
#      10     stepwise_selection_qic_forward(df, df["HHIDPN"], indep_corr,
#      11                         sm.families.Binomial(),
#      12                         baseFormula, fullFormula,
#      13                         verbose=False,
#      14                         qic_threshold=10)
#
# Cell In[115], line 76, in stepwise_selection_qic_forward(data, groups, cov_struct, family, start_formula, end_formula, verbose, qic_threshold)
#      74 try:
#      75     model = smf.gee(formula, groups=groups, data=data, cov_struct=cov_struct, family=family)
# ---> 76     result = model.fit(cov_type="robust")
#      77     qic = calc_qic(result)
#      78 except Exception:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\statsmodels\genmod\generalized_estimating_equations.py:1270, in GEE.fit(self, maxiter, ctol, start_params, params_niter, first_dep_update, cov_type, ddof_scale, scaling_factor, scale)
#    1267 num_assoc_updates = 0
#    1268 for itr in range(maxiter):
# -> 1270     update, score = self._update_mean_params()
#    1271     if update is None:
#    1272         warnings.warn("Singular matrix encountered in GEE update",
#    1273                       ConvergenceWarning)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\statsmodels\genmod\generalized_estimating_equations.py:1061, in GEE._update_mean_params(self)
#    1058     wresid = resid
#    1059     wdmat = dmat
# -> 1061 rslt = self.cov_struct.covariance_matrix_solve(
#    1062         expval, i, sdev, (wdmat, wresid))
#    1063 if rslt is None:
#    1064     return None, None
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\statsmodels\genmod\cov_struct.py:974, in Autoregressive.covariance_matrix_solve(self, expval, index, stdev, rhs)
#     972 z0 = np.zeros((1, x1.shape[1]))
#     973 rhs1 = np.concatenate((x1[1:, :], z0), axis=0)
# --> 974 rhs2 = np.concatenate((z0, x1[0:-1, :]), axis=0)
#     976 y = c0 * x1 + c2 * rhs1 + c2 * rhs2
#     977 y[0, :] = c1 * x1[0, :] + c2 * x1[1, :]
#
# KeyboardInterrupt:

# %%
print("Best formula of Exchangeble Covariance:", bestExchForm)
print("Best formula of AR(1) Covariance:", bestARForm)
print("Best formula of Indepedence Covariance:", bestIndepForm)

print("Best qic of Exchangeble Covariance:", ExchHistory[-1][1])
print("Best qic of AR(1) Covariance:", ARHistory[-1][1])
print("Best qic of Indepedence Covariance:", IndepHistory[-1][1])
# Out:
# Best formula of Exchangeble Covariance: RwRecProp ~ RwAGEM_B * C(RwJOCCSD, Treatment(reference='Retired')) + RwJLIFT + RwSMOKEV
# Best formula of AR(1) Covariance: RwRecProp ~ RAEDYRS + RAGENDER + RwAGEM_B * C(RwJOCCSD, Treatment(reference='Retired'))
# Best formula of Indepedence Covariance: RwRecProp ~ RwAGEM_B * C(RwJOCCSD, Treatment(reference='Retired')) + RwWGIHR
# Best qic of Exchangeble Covariance: -408.78824872787925
# Best qic of AR(1) Covariance: 476.7440560651559
# Best qic of Indepedence Covariance: 87.33868652831293

# %%
print("Best formula of Exchangeble Covariance:", bestExchResult.summary().tables[1])
print("Best formula of AR(1) Covariance:", bestARResult.summary().tables[1])
print("Best formula of Indepedence Covariance:", bestIndepResult.summary().tables[1])
# Out:
# Best formula of Exchangeble Covariance: ============================================================================================================================================================
#                                                                                                coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------------------------------------------------
# Intercept                                                                                    0.3182        nan        nan        nan         nan         nan
# C(RwJOCCSD, Treatment(reference='Retired'))[T.Farming/Forestry/Fishing]                     -0.5736        nan        nan        nan         nan         nan
# C(RwJOCCSD, Treatment(reference='Retired'))[T.Food/Personal/Service]                         1.0898        nan        nan        nan         nan         nan
# C(RwJOCCSD, Treatment(reference='Retired'))[T.Healthcare]                                    0.7448        nan        nan        nan         nan         nan
# C(RwJOCCSD, Treatment(reference='Retired'))[T.High Risk Occupations]                         1.3904        nan        nan        nan         nan         nan
# C(RwJOCCSD, Treatment(reference='Retired'))[T.Management/Clerical/Business]                  1.0044        nan        nan        nan         nan         nan
# C(RwJOCCSD, Treatment(reference='Retired'))[T.STEM/Professional/Technical]                   0.6753        nan        nan        nan         nan         nan
# C(RwJOCCSD, Treatment(reference='Retired'))[T.Sales]                                         1.0270        nan        nan        nan         nan         nan
# C(RwJOCCSD, Treatment(reference='Retired'))[T.Skilled Trades/Production/Manual]              0.8642        nan        nan        nan         nan         nan
# RwAGEM_B                                                                                    -0.0198        nan        nan        nan         nan         nan
# RwAGEM_B:C(RwJOCCSD, Treatment(reference='Retired'))[T.Farming/Forestry/Fishing]             0.0222        nan        nan        nan         nan         nan
# RwAGEM_B:C(RwJOCCSD, Treatment(reference='Retired'))[T.Food/Personal/Service]               -0.0056        nan        nan        nan         nan         nan
# RwAGEM_B:C(RwJOCCSD, Treatment(reference='Retired'))[T.Healthcare]                           0.0047        nan        nan        nan         nan         nan
# RwAGEM_B:C(RwJOCCSD, Treatment(reference='Retired'))[T.High Risk Occupations]               -0.0089        nan        nan        nan         nan         nan
# RwAGEM_B:C(RwJOCCSD, Treatment(reference='Retired'))[T.Management/Clerical/Business]         0.0021        nan        nan        nan         nan         nan
# RwAGEM_B:C(RwJOCCSD, Treatment(reference='Retired'))[T.STEM/Professional/Technical]          0.0100        nan        nan        nan         nan         nan
# RwAGEM_B:C(RwJOCCSD, Treatment(reference='Retired'))[T.Sales]                            -9.217e-05        nan        nan        nan         nan         nan
# RwAGEM_B:C(RwJOCCSD, Treatment(reference='Retired'))[T.Skilled Trades/Production/Manual]    -0.0020        nan        nan        nan         nan         nan
# RwJLIFT                                                                                     -0.0903      0.096     -0.944      0.345      -0.278       0.097
# RwSMOKEV                                                                                    -0.0750      0.061     -1.228      0.219      -0.195       0.045
# ============================================================================================================================================================
# Best formula of AR(1) Covariance: ============================================================================================================================================================
#                                                                                                coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------------------------------------------------
# Intercept                                                                                    1.0123      0.168      6.039      0.000       0.684       1.341
# RAGENDER[T.M]                                                                               -0.2578      0.037     -7.042      0.000      -0.330      -0.186
# C(RwJOCCSD, Treatment(reference='Retired'))[T.Farming/Forestry/Fishing]                     -2.1540      1.987     -1.084      0.278      -6.047       1.739
# C(RwJOCCSD, Treatment(reference='Retired'))[T.Food/Personal/Service]                        -0.0588      0.697     -0.084      0.933      -1.425       1.307
# C(RwJOCCSD, Treatment(reference='Retired'))[T.Healthcare]                                   -0.9183      0.820     -1.120      0.263      -2.525       0.689
# C(RwJOCCSD, Treatment(reference='Retired'))[T.High Risk Occupations]                         2.2276      2.765      0.806      0.420      -3.191       7.647
# C(RwJOCCSD, Treatment(reference='Retired'))[T.Management/Clerical/Business]                 -0.4572      0.419     -1.092      0.275      -1.278       0.364
# C(RwJOCCSD, Treatment(reference='Retired'))[T.STEM/Professional/Technical]                  -0.6017      0.545     -1.105      0.269      -1.669       0.466
# C(RwJOCCSD, Treatment(reference='Retired'))[T.Sales]                                        -1.1995      0.385     -3.113      0.002      -1.955      -0.444
# C(RwJOCCSD, Treatment(reference='Retired'))[T.Skilled Trades/Production/Manual]             -0.0936      0.618     -0.151      0.880      -1.305       1.118
# RAEDYRS                                                                                      0.0825      0.006     13.857      0.000       0.071       0.094
# RwAGEM_B                                                                                    -0.0318      0.002    -14.396      0.000      -0.036      -0.027
# RwAGEM_B:C(RwJOCCSD, Treatment(reference='Retired'))[T.Farming/Forestry/Fishing]             0.0376      0.033      1.125      0.260      -0.028       0.103
# RwAGEM_B:C(RwJOCCSD, Treatment(reference='Retired'))[T.Food/Personal/Service]                0.0004      0.011      0.032      0.975      -0.021       0.022
# RwAGEM_B:C(RwJOCCSD, Treatment(reference='Retired'))[T.Healthcare]                           0.0135      0.014      0.955      0.340      -0.014       0.041
# RwAGEM_B:C(RwJOCCSD, Treatment(reference='Retired'))[T.High Risk Occupations]               -0.0388      0.048     -0.816      0.414      -0.132       0.054
# RwAGEM_B:C(RwJOCCSD, Treatment(reference='Retired'))[T.Management/Clerical/Business]         0.0085      0.007      1.278      0.201      -0.005       0.022
# RwAGEM_B:C(RwJOCCSD, Treatment(reference='Retired'))[T.STEM/Professional/Technical]          0.0118      0.009      1.340      0.180      -0.005       0.029
# RwAGEM_B:C(RwJOCCSD, Treatment(reference='Retired'))[T.Sales]                                0.0199      0.006      3.208      0.001       0.008       0.032
# RwAGEM_B:C(RwJOCCSD, Treatment(reference='Retired'))[T.Skilled Trades/Production/Manual]    -0.0006      0.010     -0.058      0.953      -0.021       0.020
# ============================================================================================================================================================
# Best formula of Indepedence Covariance: ============================================================================================================================================================
#                                                                                                coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------------------------------------------------
# Intercept                                                                                    1.7154      1.089      1.575      0.115      -0.419       3.850
# C(RwJOCCSD, Treatment(reference='Retired'))[T.Farming/Forestry/Fishing]                     -1.7786      2.035     -0.874      0.382      -5.767       2.210
# C(RwJOCCSD, Treatment(reference='Retired'))[T.Food/Personal/Service]                        -0.3126      1.458     -0.214      0.830      -3.171       2.546
# C(RwJOCCSD, Treatment(reference='Retired'))[T.Healthcare]                                   -1.1171      1.350     -0.827      0.408      -3.763       1.529
# C(RwJOCCSD, Treatment(reference='Retired'))[T.High Risk Occupations]                         0.0182      1.646      0.011      0.991      -3.208       3.244
# C(RwJOCCSD, Treatment(reference='Retired'))[T.Management/Clerical/Business]                 -0.8652      1.144     -0.756      0.449      -3.107       1.377
# C(RwJOCCSD, Treatment(reference='Retired'))[T.STEM/Professional/Technical]                  -0.9655      1.222     -0.790      0.429      -3.360       1.429
# C(RwJOCCSD, Treatment(reference='Retired'))[T.Sales]                                        -0.7047      1.264     -0.558      0.577      -3.182       1.772
# C(RwJOCCSD, Treatment(reference='Retired'))[T.Skilled Trades/Production/Manual]             -0.4920      1.241     -0.397      0.692      -2.924       1.940
# RwAGEM_B                                                                                    -0.0303      0.018     -1.672      0.094      -0.066       0.005
# RwAGEM_B:C(RwJOCCSD, Treatment(reference='Retired'))[T.Farming/Forestry/Fishing]             0.0278      0.033      0.832      0.405      -0.038       0.093
# RwAGEM_B:C(RwJOCCSD, Treatment(reference='Retired'))[T.Food/Personal/Service]                0.0052      0.024      0.218      0.827      -0.042       0.052
# RwAGEM_B:C(RwJOCCSD, Treatment(reference='Retired'))[T.Healthcare]                           0.0219      0.023      0.961      0.337      -0.023       0.066
# RwAGEM_B:C(RwJOCCSD, Treatment(reference='Retired'))[T.High Risk Occupations]            -8.873e-05      0.027     -0.003      0.997      -0.053       0.053
# RwAGEM_B:C(RwJOCCSD, Treatment(reference='Retired'))[T.Management/Clerical/Business]         0.0197      0.019      1.036      0.300      -0.018       0.057
# RwAGEM_B:C(RwJOCCSD, Treatment(reference='Retired'))[T.STEM/Professional/Technical]          0.0239      0.020      1.177      0.239      -0.016       0.064
# RwAGEM_B:C(RwJOCCSD, Treatment(reference='Retired'))[T.Sales]                                0.0146      0.021      0.697      0.486      -0.026       0.055
# RwAGEM_B:C(RwJOCCSD, Treatment(reference='Retired'))[T.Skilled Trades/Production/Manual]     0.0059      0.021      0.286      0.775      -0.035       0.047
# RwWGIHR                                                                                      0.0005      0.000      1.349      0.177      -0.000       0.001
# ============================================================================================================================================================

# %%
bestExchForm = "RwRecProp ~ C(RwJOCCSD, Treatment(reference='Retired')) + RAEDYRS + RwAGEM_B + RwJLIFT + RwWGIHR"

# %% [markdown]
# ### 2.2 Manual Variable Selection

# %%
# resultsExchFull = fitBaseModel(fullFormula, "HHIDPN", df, exchangeable_corr, sm.families.Binomial())
# print("Exchangeable complete!\n")
# try:
#     resultsARFull = fitBaseModel(fullFormula, "HHIDPN", df, autoregress_corr, sm.families.Binomial())
#     print("AR(1) complete!\n")
# except ValueError:
#     print("Value Error")
resultsIndepFull = fitBaseModel(fullFormula, "HHIDPN", df, indep_corr, sm.families.Binomial())
print("Independent complete!\n")
# Out:
#                                GEE Regression Results
# ===================================================================================
# Dep. Variable:                   RwRecProp   No. Observations:                13695
# Model:                                 GEE   No. clusters:                     6582
# Method:                        Generalized   Min. cluster size:                   1
#                       Estimating Equations   Max. cluster size:                  11
# Family:                           Binomial   Mean cluster size:                 2.1
# Dependence structure:         Independence   Num. iterations:                     3
# Date:                     Sat, 28 Jun 2025   Scale:                           1.000
# Covariance type:                    robust   Time:                         04:04:00
# ============================================================================================================================================================
#                                                                                                coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------------------------------------------------
# Intercept                                                                                    0.3314      0.047      7.093      0.000       0.240       0.423
# C(RwJOCCSD, Treatment(reference='Retired'))[T.Farming/Forestry/Fishing]                      0.1225      0.281      0.436      0.663      -0.429       0.674
# C(RwJOCCSD, Treatment(reference='Retired'))[T.Food/Personal/Service]                        -0.0732      0.133     -0.549      0.583      -0.335       0.188
# C(RwJOCCSD, Treatment(reference='Retired'))[T.Healthcare]                                   -0.4149      0.235     -1.767      0.077      -0.875       0.045
# C(RwJOCCSD, Treatment(reference='Retired'))[T.High Risk Occupations]                         0.6047      0.290      2.087      0.037       0.037       1.173
# C(RwJOCCSD, Treatment(reference='Retired'))[T.Management/Clerical/Business]                 -0.0588      0.110     -0.535      0.593      -0.274       0.157
# C(RwJOCCSD, Treatment(reference='Retired'))[T.STEM/Professional/Technical]                   0.1661      0.135      1.230      0.219      -0.099       0.431
# C(RwJOCCSD, Treatment(reference='Retired'))[T.Sales]                                         0.2255      0.150      1.508      0.132      -0.068       0.519
# C(RwJOCCSD, Treatment(reference='Retired'))[T.Skilled Trades/Production/Manual]             -0.2404      0.125     -1.918      0.055      -0.486       0.005
# RwLIVBRO[T.3--8]                                                                            -0.0288      0.025     -1.159      0.246      -0.078       0.020
# RwLIVBRO[T.9--14]                                                                           -0.0144      0.175     -0.082      0.934      -0.357       0.328
# RwPhyLim[T.True]                                                                            -0.0727      0.019     -3.763      0.000      -0.111      -0.035
# RwCogLim[T.True]                                                                            -0.0882      0.016     -5.499      0.000      -0.120      -0.057
# RAGENDER[T.M]                                                                               -0.2737      0.016    -17.057      0.000      -0.305      -0.242
# RARACEM[T.Others]                                                                            0.0914      0.039      2.330      0.020       0.015       0.168
# RARACEM[T.White]                                                                             0.2279      0.021     11.039      0.000       0.187       0.268
# RwAGEM_B                                                                                    -0.0180      0.001    -15.859      0.000      -0.020      -0.016
# RwAGEM_B:C(RwJOCCSD, Treatment(reference='Retired'))[T.Farming/Forestry/Fishing]            -0.0039      0.004     -0.876      0.381      -0.013       0.005
# RwAGEM_B:C(RwJOCCSD, Treatment(reference='Retired'))[T.Food/Personal/Service]               -0.0011      0.002     -0.530      0.596      -0.005       0.003
# RwAGEM_B:C(RwJOCCSD, Treatment(reference='Retired'))[T.Healthcare]                           0.0047      0.004      1.197      0.231      -0.003       0.012
# RwAGEM_B:C(RwJOCCSD, Treatment(reference='Retired'))[T.High Risk Occupations]               -0.0112      0.005     -2.372      0.018      -0.021      -0.002
# RwAGEM_B:C(RwJOCCSD, Treatment(reference='Retired'))[T.Management/Clerical/Business]        -0.0002      0.002     -0.099      0.921      -0.004       0.003
# RwAGEM_B:C(RwJOCCSD, Treatment(reference='Retired'))[T.STEM/Professional/Technical]         -0.0030      0.002     -1.377      0.168      -0.007       0.001
# RwAGEM_B:C(RwJOCCSD, Treatment(reference='Retired'))[T.Sales]                               -0.0047      0.002     -1.982      0.047      -0.009   -5.33e-05
# RwAGEM_B:C(RwJOCCSD, Treatment(reference='Retired'))[T.Skilled Trades/Production/Manual]     0.0015      0.002      0.701      0.483      -0.003       0.006
# RwWORK                                                                                       0.3314      0.047      7.093      0.000       0.240       0.423
# RwJHOURS                                                                                    -0.0001      0.000     -0.340      0.734      -0.001       0.001
# RwWGIHR                                                                                   1.028e-06   1.28e-06      0.805      0.421   -1.47e-06    3.53e-06
# RwJPHYS                                                                                     -0.0401      0.016     -2.565      0.010      -0.071      -0.009
# RwJLIFT                                                                                     -0.0277      0.023     -1.218      0.223      -0.072       0.017
# RwJSTRES                                                                                    -0.0065      0.013     -0.496      0.620      -0.032       0.019
# RwJSTOOP                                                                                     0.0131      0.018      0.731      0.465      -0.022       0.048
# RwJSIGHT                                                                                     0.0341      0.018      1.909      0.056      -0.001       0.069
# RwCENREG                                                                                     0.0107      0.007      1.476      0.140      -0.004       0.025
# RwMSTAT                                                                                     -0.0075      0.003     -2.555      0.011      -0.013      -0.002
# RwHIBP                                                                                      -0.0206      0.013     -1.555      0.120      -0.047       0.005
# RwDIAB                                                                                      -0.0544      0.017     -3.163      0.002      -0.088      -0.021
# RwCANCR                                                                                      0.0029      0.021      0.138      0.890      -0.038       0.043
# RwLUNG                                                                                       0.0271      0.026      1.037      0.300      -0.024       0.078
# RwHEART                                                                                     -0.0287      0.017     -1.673      0.094      -0.062       0.005
# RwSTROK                                                                                     -0.0603      0.036     -1.680      0.093      -0.131       0.010
# RwPSYCH                                                                                     -0.0155      0.022     -0.709      0.478      -0.058       0.027
# RwVIGACT                                                                                    -0.0471      0.013     -3.625      0.000      -0.073      -0.022
# RwSMOKEV                                                                                     0.0096      0.014      0.666      0.506      -0.019       0.038
# RwDRINK                                                                                      0.0299      0.014      2.207      0.027       0.003       0.056
# RwAnyCogImp                                                                                       0          0        nan        nan           0           0
# RAEDYRS                                                                                      0.0499      0.003     17.328      0.000       0.044       0.056
# RAEVBRN                                                                                     -0.0014      0.004     -0.339      0.734      -0.009       0.007
# ==============================================================================
# Skew:                          0.1165   Kurtosis:                       0.2959
# Centered skew:                -0.0751   Centered kurtosis:              2.5685
# ==============================================================================
# Independent complete!

# %%
qic_exch_full = calc_qic(resultsExchFull)
# qic_ar_full = calc_qic(resultsARFull)
qic_indep_full = calc_qic(resultsIndepFull)

print(f"QIC (Exchangeable): {qic_exch_full}")
# print(f"QIC (Autoregressive): {qic_ar_full}")
print(f"QIC (Unstructured): {qic_indep_full}")
# Out:
# C:\Users\86139\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\statsmodels\genmod\generalized_estimating_equations.py:1934: UserWarning: QIC values obtained using scale=None are not appropriate for comparing models
#   warnings.warn("QIC values obtained using scale=None are not "
# QIC (Exchangeable): nan
# QIC (Unstructured): 1315.209855127156

# %%
import pandas as pd

# Manually enter the summary table as a list of dictionaries
summary_data = [
    {"Variable": "RARACEM[T.White]", "Coef": 0.2279, "P>|z|": 0.000},
    {"Variable": "RARACEM[T.Others]", "Coef": 0.0914, "P>|z|": 0.020},
    {"Variable": "C(RwJOCCSD, Treatment(reference='Retired'))[T.High Risk Occupations]", "Coef": 0.6047, "P>|z|": 0.037},
    {"Variable": "RwDRINK", "Coef": 0.0299, "P>|z|": 0.027},
    {"Variable": "Intercept", "Coef": 0.3314, "P>|z|": 0.000},
    {"Variable": "RwWORK", "Coef": 0.3314, "P>|z|": 0.000},
    {"Variable": "RAEDYRS", "Coef": 0.0499, "P>|z|": 0.000},
    {"Variable": "RwJPHYS", "Coef": -0.0401, "P>|z|": 0.010},
    {"Variable": "RwVIGACT", "Coef": -0.0471, "P>|z|": 0.000},
    {"Variable": "RwMSTAT", "Coef": -0.0075, "P>|z|": 0.011},
    {"Variable": "RwDIAB", "Coef": -0.0544, "P>|z|": 0.002},
    {"Variable": "RwPhyLim[T.True]", "Coef": -0.0727, "P>|z|": 0.000},
    {"Variable": "RwCogLim[T.True]", "Coef": -0.0882, "P>|z|": 0.000},
    {"Variable": "RAGENDER[T.M]", "Coef": -0.2737, "P>|z|": 0.000},
    {"Variable": "RwAGEM_B", "Coef": -0.0180, "P>|z|": 0.000},
    {"Variable": "RwAGEM_B:C(RwJOCCSD, Treatment(reference='Retired'))[T.High Risk Occupations]", "Coef": -0.0112, "P>|z|": 0.018},
    {"Variable": "RwAGEM_B:C(RwJOCCSD, Treatment(reference='Retired'))[T.Sales]", "Coef": -0.0047, "P>|z|": 0.047},
]

# Create the DataFrame
summary_df = pd.DataFrame(summary_data)

# Display the DataFrame
summary_df
# Out:
#                                              Variable    Coef  P>|z|
# 0                                    RARACEM[T.White]  0.2279  0.000
# 1                                   RARACEM[T.Others]  0.0914  0.020
# 2   C(RwJOCCSD, Treatment(reference='Retired'))[T....  0.6047  0.037
# 3                                             RwDRINK  0.0299  0.027
# 4                                           Intercept  0.3314  0.000
# 5                                              RwWORK  0.3314  0.000
# 6                                             RAEDYRS  0.0499  0.000
# 7                                             RwJPHYS -0.0401  0.010
# 8                                            RwVIGACT -0.0471  0.000
# 9                                             RwMSTAT -0.0075  0.011
# 10                                             RwDIAB -0.0544  0.002
# 11                                   RwPhyLim[T.True] -0.0727  0.000
# 12                                   RwCogLim[T.True] -0.0882  0.000
# 13                                      RAGENDER[T.M] -0.2737  0.000
# 14                                           RwAGEM_B -0.0180  0.000
# 15  RwAGEM_B:C(RwJOCCSD, Treatment(reference='Reti... -0.0112  0.018
# 16  RwAGEM_B:C(RwJOCCSD, Treatment(reference='Reti... -0.0047  0.047

# %%
# bestExchForm = baseFormula + ' + ' + ' + '.join([])
# bestARForm = baseFormula + ' + ' + ' + '.join([])
bestIndepForm = baseFormula + ' + ' + ' + '.join(["RARACEM", "RAEDYRS", "RwVIGACT", "RwDRINK", 
                                                 "RwMSTAT", "RwDIAB", "RwPhyLim", "RwCogLim", 
                                                 "RAGENDER"])

# bestExchResult = fitBaseModel(bestExchForm, "HHIDPN", df, exchangeable_corr, sm.families.Binomial())
# print("Exchangeable complete!\n")
# bestARResult = fitBaseModel(bestARForm, "HHIDPN", df, autoregress_corr, sm.families.Binomial())
# print("AR(1) complete!\n")
bestIndepResult = fitBaseModel(bestIndepForm, "HHIDPN", df, indep_corr, sm.families.Binomial())
print("Independent complete!\n")

# bestIndepResult.summary()
# Out:
#                                GEE Regression Results
# ===================================================================================
# Dep. Variable:                   RwRecProp   No. Observations:                80942
# Model:                                 GEE   No. clusters:                    18555
# Method:                        Generalized   Min. cluster size:                   1
#                       Estimating Equations   Max. cluster size:                  11
# Family:                           Binomial   Mean cluster size:                 4.4
# Dependence structure:         Independence   Num. iterations:                     2
# Date:                     Sat, 28 Jun 2025   Scale:                           1.000
# Covariance type:                    robust   Time:                         07:53:12
# ============================================================================================================================================================
#                                                                                                coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------------------------------------------------
# Intercept                                                                                    1.1902      0.036     32.655      0.000       1.119       1.262
# C(RwJOCCSD, Treatment(reference='Retired'))[T.Farming/Forestry/Fishing]                     -0.6754      0.265     -2.548      0.011      -1.195      -0.156
# C(RwJOCCSD, Treatment(reference='Retired'))[T.Food/Personal/Service]                        -0.7599      0.126     -6.022      0.000      -1.007      -0.513
# C(RwJOCCSD, Treatment(reference='Retired'))[T.Healthcare]                                   -1.0033      0.265     -3.793      0.000      -1.522      -0.485
# C(RwJOCCSD, Treatment(reference='Retired'))[T.High Risk Occupations]                        -0.1180      0.296     -0.399      0.690      -0.698       0.462
# C(RwJOCCSD, Treatment(reference='Retired'))[T.Management/Clerical/Business]                 -0.7398      0.095     -7.755      0.000      -0.927      -0.553
# C(RwJOCCSD, Treatment(reference='Retired'))[T.STEM/Professional/Technical]                  -0.3930      0.122     -3.229      0.001      -0.632      -0.154
# C(RwJOCCSD, Treatment(reference='Retired'))[T.Sales]                                        -0.4013      0.140     -2.870      0.004      -0.675      -0.127
# C(RwJOCCSD, Treatment(reference='Retired'))[T.Skilled Trades/Production/Manual]             -0.8774      0.107     -8.230      0.000      -1.086      -0.668
# RARACEM[T.Others]                                                                            0.0970      0.021      4.591      0.000       0.056       0.138
# RARACEM[T.White]                                                                             0.2342      0.011     21.098      0.000       0.212       0.256
# RwPhyLim[T.True]                                                                            -0.1234      0.007    -16.506      0.000      -0.138      -0.109
# RwCogLim[T.True]                                                                            -0.1846      0.007    -26.400      0.000      -0.198      -0.171
# RAGENDER[T.M]                                                                               -0.2785      0.008    -34.086      0.000      -0.295      -0.263
# RwAGEM_B                                                                                    -0.0299      0.000    -61.536      0.000      -0.031      -0.029
# RwAGEM_B:C(RwJOCCSD, Treatment(reference='Retired'))[T.Farming/Forestry/Fishing]             0.0113      0.004      2.750      0.006       0.003       0.019
# RwAGEM_B:C(RwJOCCSD, Treatment(reference='Retired'))[T.Food/Personal/Service]                0.0125      0.002      6.212      0.000       0.009       0.016
# RwAGEM_B:C(RwJOCCSD, Treatment(reference='Retired'))[T.Healthcare]                           0.0167      0.004      3.763      0.000       0.008       0.025
# RwAGEM_B:C(RwJOCCSD, Treatment(reference='Retired'))[T.High Risk Occupations]                0.0031      0.005      0.655      0.512      -0.006       0.012
# RwAGEM_B:C(RwJOCCSD, Treatment(reference='Retired'))[T.Management/Clerical/Business]         0.0132      0.002      8.525      0.000       0.010       0.016
# RwAGEM_B:C(RwJOCCSD, Treatment(reference='Retired'))[T.STEM/Professional/Technical]          0.0079      0.002      4.036      0.000       0.004       0.012
# RwAGEM_B:C(RwJOCCSD, Treatment(reference='Retired'))[T.Sales]                                0.0077      0.002      3.514      0.000       0.003       0.012
# RwAGEM_B:C(RwJOCCSD, Treatment(reference='Retired'))[T.Skilled Trades/Production/Manual]     0.0141      0.002      8.005      0.000       0.011       0.018
# RAEDYRS                                                                                      0.0542      0.001     41.574      0.000       0.052       0.057
# RwVIGACT                                                                                    -0.0067      0.007     -1.027      0.305      -0.019       0.006
# RwDRINK                                                                                      0.0742      0.007     10.575      0.000       0.060       0.088
# RwMSTAT                                                                                     -0.0074      0.001     -5.319      0.000      -0.010      -0.005
# RwDIAB                                                                                      -0.0541      0.009     -6.360      0.000      -0.071      -0.037
# ==============================================================================
# Skew:                          0.0662   Kurtosis:                       0.1887
# Centered skew:                 0.0243   Centered kurtosis:              1.0666
# ==============================================================================
# Independent complete!

# %%
bestIndepForm
# Out:
# "RwRecProp ~ RwAGEM_B * C(RwJOCCSD, Treatment(reference='Retired')) + RAEDYRS + RwVIGACT + RwMSTAT + RwDIAB + RwPhyLim + RwCogLim + RAGENDER"

# %% [markdown]
# ## 3. Test Error Rate Comparison

# %%
from sklearn.metrics import mean_absolute_error
import numpy as np

def getPredError(model, respVar, testSet, maxScore):
    '''
    Get prediction error on the testing set
    '''
    testSet = testSet.reset_index(drop=True)
    pred = model.get_prediction(exog=testSet)
    predicted_prop = pred.predicted_mean
    predicted_value = maxScore * np.asarray(predicted_prop).flatten()
    actual_value = testSet[respVar]
    
    # Remove rows where either prediction or actual is NaN
    mask = ~np.isnan(predicted_value) & ~np.isnan(actual_value)
    predicted_value = predicted_value[mask]
    actual_value = actual_value[mask]
    
    print("Actual:", actual_value)
    print("Predicted:", predicted_value)
    MAE_loss = mean_absolute_error(actual_value, predicted_value*dropna())
    print(MAE_loss)

getPredError(bestIndepResult, "RwTR20", df, 20)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[256], line 24
#      21     MAE_loss = mean_absolute_error(actual_value, predicted_value*dropna())
#      22     print(MAE_loss)
# ---> 24 getPredError(bestIndepResult, "RwTR20", df, 20)
#
# Cell In[256], line 15, in getPredError(model, respVar, testSet, maxScore)
#      12 actual_value = testSet[respVar]
#      14 # Remove rows where either prediction or actual is NaN
# ---> 15 mask = ~np.isnan(predicted_value) & ~np.isnan(actual_value)
#      16 predicted_value = predicted_value[mask]
#      17 actual_value = actual_value[mask]
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\generic.py:2171, in NDFrame.__array_ufunc__(self, ufunc, method, *inputs, **kwargs)
#    2167 @final
#    2168 def __array_ufunc__(
#    2169     self, ufunc: np.ufunc, method: str, *inputs: Any, **kwargs: Any
#    2170 ):
# -> 2171     return arraylike.array_ufunc(self, ufunc, method, *inputs, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\arraylike.py:276, in array_ufunc(self, ufunc, method, *inputs, **kwargs)
#     273 kwargs = _standardize_out_kwarg(**kwargs)
#     275 # for binary ops, use our custom dunder methods
# --> 276 result = maybe_dispatch_ufunc_to_dunder_op(self, ufunc, method, *inputs, **kwargs)
#     277 if result is not NotImplemented:
#     278     return result
#
# File ops_dispatch.pyx:113, in pandas._libs.ops_dispatch.maybe_dispatch_ufunc_to_dunder_op()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\ops\common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\arraylike.py:74, in OpsMixin.__rand__(self, other)
#      72 @unpack_zerodim_and_defer("__rand__")
#      73 def __rand__(self, other):
# ---> 74     return self._logical_method(other, roperator.rand_)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\series.py:6130, in Series._logical_method(self, other, op)
#    6127 lvalues = self._values
#    6128 rvalues = extract_array(other, extract_numpy=True, extract_range=True)
# -> 6130 res_values = ops.logical_op(lvalues, rvalues, op)
#    6131 return self._construct_result(res_values, name=res_name)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\ops\array_ops.py:454, in logical_op(left, right, op)
#     450 else:
#     451     # i.e. scalar
#     452     is_other_int_dtype = lib.is_integer(rvalues)
# --> 454 res_values = na_logical_op(lvalues, rvalues, op)
#     456 # For int vs int `^`, `|`, `&` are bitwise operators and return
#     457 #   integer dtypes.  Otherwise these are boolean ops
#     458 if not (left.dtype.kind in "iu" and is_other_int_dtype):
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\ops\array_ops.py:362, in na_logical_op(x, y, op)
#     352 def na_logical_op(x: np.ndarray, y, op):
#     353     try:
#     354         # For exposition, write:
#     355         #  yarr = isinstance(y, np.ndarray)
#    (...)    360         # Then Cases where this goes through without raising include:
#     361         #  (xint or xbool) and (yint or bool)
# --> 362         result = op(x, y)
#     363     except TypeError:
#     364         if isinstance(y, np.ndarray):
#     365             # bool-bool dtype operations should be OK, should not get here
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\roperator.py:54, in rand_(left, right)
#      53 def rand_(left, right):
# ---> 54     return operator.and_(right, left)
#
# ValueError: operands could not be broadcast together with shapes (90689,) (91354,)

# %% [markdown]
# ## 3. Automated Hypothesis Testing

# %%
import re

# ## A List of parameters
param_names = bestIndepResult.params.index.tolist()

# ## Create joint hypothesis tests for "No interactions"
interaction_pattern = re.compile(r"RwAGEM_B:C\(RwJOCCSD,")
interaction_indices = [i for i, name in enumerate(param_names) if interaction_pattern.search(name)]
interaction_matrix = np.zeros((len(interaction_indices), len(param_names)))
for row, idx in enumerate(interaction_indices):
    interaction_matrix[row, idx] = 1

## Create joint hypothesis tests for "No main effect"
main_pattern = re.compile(r"^C\(RwJOCCSD,")
main_indices = [i for i, name in enumerate(param_names) if main_pattern.search(name)]
main_matrix = np.zeros((len(main_indices), len(param_names)))
for row, idx in enumerate(main_indices):
    main_matrix[row, idx] = 1

# ## Create the hypothesis test for STEM superior
# stem_matrix = np.zeros((1, len(param_names)))
# hypo_coef = [-1, -1, -1, -1, -1, 7, -1, -1]
# for j in list(range(0, len(main_indices))):
#     stem_matrix[0, main_indices[j]] = hypo_coef[j]

# ## Create the hypothesis test for Management superior
# mgmt_matrix = np.zeros((1, len(param_names)))
# hypo_coef = [-1, -1, -1, -1, 7, -1, -1, -1]
# for j in list(range(0, len(main_indices))):
#     mgmt_matrix[0, main_indices[j]] = hypo_coef[j]


# ## Create the hypothesis test for food inferior
# food_matrix = np.zeros((1, len(param_names)))
# hypo_coef = [-1, 7, -1, -1, -1, -1, -1, -1]
# for j in list(range(0, len(main_indices))):
#     food_matrix[0, main_indices[j]] = hypo_coef[j]

# ## Create the hypothesis test for farm inferior
# farm_matrix = np.zeros((1, len(param_names)))
# hypo_coef = [7, -1, -1, -1, -1, -1, -1, -1]
# for j in list(range(0, len(main_indices))):
#     farm_matrix[0, main_indices[j]] = hypo_coef[j]

# %%
def testSummary(r_matrix, model):
    wald_res = model.wald_test(r_matrix)
    print("Statistic:", wald_res.statistic[0,0])
    print("Degrees of freedom:", wald_res.df_denom)
    print("p-value:", wald_res.pvalue)
    print("Distribution:", wald_res.distribution)

def serialTest(model, varPattern):
    '''
    Test multipe similar null hypothesis independently
    '''
    param_names = model.params.index.tolist()

    # Indices of interested parameters
    main_pattern = re.compile(varPattern)
    main_indices = [i for i, name in enumerate(param_names) if main_pattern.search(name)]

    l = len(main_indices)
    for j in list(range(0, l)):
        ## Hypothesis Coefficients
        hypo_coef = np.full((1, l), -1/l)
        hypo_coef[0, j] = 1

        ## Map hypo_coef to the parameter
        r_matrix = np.zeros((1, len(param_names)))

        # print(hypo_coef[0,1])
        # print(main_indices)
        # print(r_matrix)
        for k in list(range(0, len(main_indices))):
            r_matrix[0, main_indices[k]] = hypo_coef[0,k]

        ## Net effect estimate
        netEffect = (r_matrix @ np.array(model.params))[0]
        print(f"Net effect of {param_names[main_indices[j]]} is {netEffect}")
        
        ## Wald test 
        testSummary(r_matrix, model)
        print("\n\n")

    
# testSummary(interaction_matrix, bestARResult)
serialTest(bestIndepResult, "^C\(RwJOCCSD,")
# Out:
# Net effect of C(RwJOCCSD, Treatment(reference='Retired'))[T.Farming/Forestry/Fishing] is -0.06894547102285697
# Statistic: 0.06263578141075488
# Degrees of freedom: 1.0
# p-value: 0.8023774603258461
# Distribution: chi2
#
#
#
# Net effect of C(RwJOCCSD, Treatment(reference='Retired'))[T.Food/Personal/Service] is -0.2883374708060271
# Statistic: 4.221754213518139
# Degrees of freedom: 1.0
# p-value: 0.039908880767751106
# Distribution: chi2
#
#
#
# Net effect of C(RwJOCCSD, Treatment(reference='Retired'))[T.Healthcare] is -0.6302088552187908
# Statistic: 5.492568548303178
# Degrees of freedom: 1.0
# p-value: 0.019097466494387223
# Distribution: chi2
#
#
#
# Net effect of C(RwJOCCSD, Treatment(reference='Retired'))[T.High Risk Occupations] is 0.4482378627486824
# Statistic: 2.1270050809326753
# Degrees of freedom: 1.0
# p-value: 0.1447232827842026
# Distribution: chi2
#
#
#
# Net effect of C(RwJOCCSD, Treatment(reference='Retired'))[T.Management/Clerical/Business] is -0.19136888896300053
# Statistic: 2.841649852858129
# Degrees of freedom: 1.0
# p-value: 0.09184986086977684
# Distribution: chi2
#
#
#
# Net effect of C(RwJOCCSD, Treatment(reference='Retired'))[T.STEM/Professional/Technical] is 0.2194140137291001
# Statistic: 2.4943010397175374
# Degrees of freedom: 1.0
# p-value: 0.11425909290879717
# Distribution: chi2
#
#
#
# Net effect of C(RwJOCCSD, Treatment(reference='Retired'))[T.Sales] is 0.2619251039576489
# Statistic: 2.9621148720886366
# Degrees of freedom: 1.0
# p-value: 0.08523638673672573
# Distribution: chi2
#
#
#
# Net effect of C(RwJOCCSD, Treatment(reference='Retired'))[T.Skilled Trades/Production/Manual] is -0.37416591716613445
# Statistic: 9.174978783630445
# Degrees of freedom: 1.0
# p-value: 0.002453462115578662
# Distribution: chi2
# C:\Users\86139\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\statsmodels\base\model.py:1912: FutureWarning: The behavior of wald_test will change after 0.14 to returning scalar test statistic values. To get the future behavior now, set scalar to True. To silence this message while retaining the legacy behavior, set scalar to False.
#   warnings.warn(

# %%
print("Interaction Effect")
testSummary(interaction_matrix, bestIndepResult)

print("Main Effect")
testSummary(main_matrix, bestIndepResult)
# Out:
# Interaction Effect
# Statistic: 183.24279260056883
# Degrees of freedom: 8.0
# p-value: 2.1452051145196688e-35
# Distribution: chi2
# Main Effect
# Statistic: 162.99028452218164
# Degrees of freedom: 8.0
# p-value: 3.788229157868425e-31
# Distribution: chi2
# C:\Users\86139\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\statsmodels\base\model.py:1912: FutureWarning: The behavior of wald_test will change after 0.14 to returning scalar test statistic values. To get the future behavior now, set scalar to True. To silence this message while retaining the legacy behavior, set scalar to False.
#   warnings.warn(

# %%
bestIndepResult.qic()
# Out:
# C:\Users\86139\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\statsmodels\genmod\generalized_estimating_equations.py:1934: UserWarning: QIC values obtained using scale=None are not appropriate for comparing models
#   warnings.warn("QIC values obtained using scale=None are not "
# (8608.505787762413, 8656.393893894128)

# %%
## Multiple tests on Interaction Terms
serialTest(bestARResult, "^RwAGEM_B:C\(RwJOCCSD,")
# Out:
# Net effect of RwAGEM_B:C(RwJOCCSD, Treatment(reference='Retired'))[T.Farming/Forestry/Fishing] is 0.035807682949691555
# Statistic: 1.1138568383756848
# Degrees of freedom: 1.0
# p-value: 0.29124509153381184
# Distribution: chi2
#
#
#
# Net effect of RwAGEM_B:C(RwJOCCSD, Treatment(reference='Retired'))[T.Food/Personal/Service] is -0.006149995862626768
# Statistic: 0.23417399573963538
# Degrees of freedom: 1.0
# p-value: 0.6284459975690349
# Distribution: chi2
#
#
#
# Net effect of RwAGEM_B:C(RwJOCCSD, Treatment(reference='Retired'))[T.Healthcare] is 0.008672970360212976
# Statistic: 0.2950677957107403
# Degrees of freedom: 1.0
# p-value: 0.5869911207533771
# Distribution: chi2
#
#
#
# Net effect of RwAGEM_B:C(RwJOCCSD, Treatment(reference='Retired'))[T.High Risk Occupations] is -0.05018521275236207
# Statistic: 1.1111731732317598
# Degrees of freedom: 1.0
# p-value: 0.29182706885164766
# Distribution: chi2
#
#
#
# Net effect of RwAGEM_B:C(RwJOCCSD, Treatment(reference='Retired'))[T.Management/Clerical/Business] is 0.0030246022191070523
# Statistic: 0.0823115814311783
# Degrees of freedom: 1.0
# p-value: 0.7741889286126566
# Distribution: chi2
#
#
#
# Net effect of RwAGEM_B:C(RwJOCCSD, Treatment(reference='Retired'))[T.STEM/Professional/Technical] is 0.006709640451374522
# Statistic: 0.332716987556369
# Degrees of freedom: 1.0
# p-value: 0.5640635902132829
# Distribution: chi2
#
#
#
# Net effect of RwAGEM_B:C(RwJOCCSD, Treatment(reference='Retired'))[T.Sales] is 0.015890388167115767
# Statistic: 2.7505890447487342
# Degrees of freedom: 1.0
# p-value: 0.09721860643413753
# Distribution: chi2
#
#
#
# Net effect of RwAGEM_B:C(RwJOCCSD, Treatment(reference='Retired'))[T.Skilled Trades/Production/Manual] is -0.007224968494368458
# Statistic: 0.33751550311514805
# Degrees of freedom: 1.0
# p-value: 0.5612668432651922
# Distribution: chi2

# %%
# Retrieve the covariance matrices of the fitted GEE models
# cov_exch = resultsExch.cov_params()
# cov_ar = resultsAR.cov_params()
# cov_unstruct = resultsUnstruct.cov_params()

# print("Covariance matrix (Exchangeable):\n", cov_exch)
# print("\nCovariance matrix (Autoregressive):\n", cov_ar)
# print("\nCovariance matrix (Unstructured):\n", cov_unstruct)
